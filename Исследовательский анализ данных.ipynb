# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Сергей, привет!👋</b>
#
# Меня зовут Юлия Булекова, я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
#
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓
#
#
# Предлагаю работать над проектом в диалоге: если ты хочешь ответить на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# </div>
#
#
#
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Юлия, привет! Спасибо, что проверила мою работу и дала экспертную оценку, буду стараться следовать всем твоим советам, для улучшения своего кода в будущем:</b>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет 🤗. Для того чтобы не создалась путаница я буду вставлять номер версии проверки в комментарии и на данном этапе мои замечания будут выглядеть таким образом:
#
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# Ты также можешь реагировать на мои комментарии своими, выделяя их цветом отличным от моего и маркируя версию 😉.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет 🤗. На данном этапе мои замечания будут выглядеть таким образом:
#
# <h2> Комментарий ревьюера #3 <a class="tocSkip"> </h2>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Сергей, привет 🙃. На данном этапе мои замечания будут выглядеть таким образом:
#
# <h2> Комментарий ревьюера #4 <a class="tocSkip"> </h2>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
#
# Здорово, что описание проекта и интерактивное оглавление добавлены в работу.👌

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# 1. Код на загрузку библиотек лучше выделить в отдельную ячейку и отделить от другой части кода, это общий стандарт оформления работы=)
#
#
# 2. Для подгрузки данных рекомендую использовать конструкцию `try-except`, она поможет избежать потенциальных ошибок при загрузке данных, связанных, например, с некорректным указанием путей.
#
# Подробнее о конструкции по ссылке:
#
# https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html
#
# Либо же можно использовать стандартную библиотеку os:
#
# https://pythonworld.ru/moduli/modul-os.html
#
# Несколько интересных статей кейсы использования конструкции `try-except`:
#
# https://www.programiz.com/python-programming/exception-handling
#
# https://towardsdatascience.com/do-not-abuse-try-except-in-python-d9b8ee59e23b
#
# https://www.techbeamers.com/use-try-except-python/
#
# 3. Было бы здорово проверить датасет в целом на наличие дубликатов. Это основа предобработки данных.
#
#
# 4. **❗Все выводы и комментарии к логике решения необходимо поместить в текстовых ячейках типа markdown❗**

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# 1. Большой плюс за использование try-except при указании путей загрузки файла 🙌
#
# 2. Как писала выше - было бы здорово отделить код на загрузку библиотек от кода на чтение файла и проверить данные на дубликаты.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

try:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') #добавил sep='\t' для разделения аргументов.
except:
    data = pd.read_csv('real_estate_data.csv', sep='\t')
#data.head(20) #вывел 20 строчек файла на экран для просмотра данных.
data.info() #вывел основную информацию о датафрейме методом info()

#вывод.
# first_day_exposition является объектом, он должен быть в формате времени(datetime), floors_total в float, а должжен быть целостным числом, это же касается balcony, is apartment должен быть bool
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.hist(figsize=(15, 20))#Построим общую гистограмму для всех числовых столбцов таблицы
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Согласно заданию на этом необходимо также выполнить такой пункт:
#
#     Постройте общую гистограмму для всех числовых столбцов таблицы. Например, для датафрейма data это можно сделать командой data.hist(figsize=(15, 20)).

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Спасибо за совет! Учту это.</b>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Отлично - теперь в нашем проекте есть общая гисторгамма 👌 Осталось убрать тех. строчку на этом графике и этот момент будет завершенным~

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента №2<a class="tocSkip"></h2>
#
# <b>Убрал.</b>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# 🙌

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# 1. Согласна с предложенными ниже способами обработки для: is_apartment и balcony🙌
#
#
#
# 2. В floors_total и days_exposition ты используешь заглушки равные нулю:
#
# -  В floors_total пропусков около 86 строк и такое количество в рамках объема наших данных можно удалить или заменить пропуск на этаж, на котором расположена недвижимость.
#
# - В days_exposition отсутствует около 14% данных и в этом параметре сложно восстановить пропуски каким-то известным способом. Если же заполнять пропуски в данных отвлеченными значениями (заглушками) - то их обязательно необходимо учитывать на последующих этапах и исключать при расчетах и визуализации данных. Дополню, что обычно заполняют пропуски заглушками в том случае, когда алгоритм, для которого готовятся данные, чувствителен к пропускам. Например, регрессии чувствительны, а корреляция нет. Для них заполнение может даже навредить, если заполнять маркерными значениями и забыть о фильтрации. ***Поэтому пропуски в этом параметре стоит сохранить.***
#
# Для изменения типа данных на целочисленный при наличии пропусков можно использовать Int64 (с большой буквы I). Для этого необходимо установить библиотеку numpy (import numpy as np) и с ее помощью округлить данные вверх или вниз. Если приводить округление данных до нижней границы, то код будет выглядеть таким образом:
#
#     data['days_exposition']=np.floor(pd.to_numeric(data['days_exposition'], errors='coerce')).astype('Int64')
# Или можно округлить данные математически без использования библиотеки numpy и тогда решение будет выглядеть таким образом:
#
#     data['days_exposition']=round(data['days_exposition']).astype('Int64')

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>C days_exposition разобрался, спасибо.
#     Floors_total пропуски сохранил
#     </b>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
#
# На всякий случай добавлю, что ниже остался код на добавление заглушки в days_exposition.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Вижу, что теперь код на добавление заглушки в days_exposition закомментирован 🤝

# %%
#Перейдем к предобработке данных для работы с пропусками и определения аномальных значений.

data.isna().sum() # Вывел количество пропущенных значений для каждого столбца. Самые большие пропуски значений в стобцах is_apartment, parks_nearest,ponds_nearest,balcony. Скорее всего потеря таких данных связана с тем, что пользователи просто не стали заполнять эти данные, так-как эта информация их не касается, например у них нет парка рядом, они пропустили ввод этой категории данных.

ceiling_height_median = data['ceiling_height'].median() #необходимо заполнить пропуски в столбце ceiling_heigh, это количественная переменная, пропущенные значения подберем через mean
#print(data['ceiling_height'].unique()) посмотрим на артефакты в ceiling_height. В значених есть потолки по 20 метров и по 100. Надо их убрать
#data = data[(data['ceiling_height'] != 26) & (data['ceiling_height'] != 20) & (data['ceiling_height'] != 8) & (data['ceiling_height'] != 32) & (data['ceiling_height'] != 27) & (data['ceiling_height'] != 25) & (data['ceiling_height'] != 100 & (data['ceiling_height'] != 24) & (data['ceiling_height'] != 22.6))] 
#print(data['ceiling_height'].unique()) посмотрим, что получилось
#print(ceiling_height_median)
#data.head(20)
data['ceiling_height'] = round(data['ceiling_height'].fillna(value=ceiling_height_median), 2) #заменили все пропуски столба ceiling_heigh на средние значение по таблице = 2.771499 , сделаем только 2 знака после запятой
data.loc[data['ceiling_height'] >= 20, 'ceiling_height'] = data['ceiling_height'] / 10
data=data.query('ceiling_height > 2.3 and ceiling_height < 5.0')

#data.head(20) #посмотрим что получилось...
#print(len(data[data['is_apartment'].isna()])) #проверим все строки в столбце is_apartment и оставляем только те, в которых есть NaN - их 20924, из 23699 пропущено 20924 - 88% данных.

data['is_apartment'] = data['is_apartment'].fillna('false') #мы заменили все значения Nan на false

#data.head(20)
#data.isna().sum() значения 'is_apartment' заполнены.

#data['days_exposition'] = data['days_exposition'].fillna('0') #№пропуски заполним нулями
data['days_exposition']=np.floor(pd.to_numeric(data['days_exposition'], errors='coerce')).astype('Int64')


data['balcony'] = data['balcony'].fillna(0) #пропуски по балконам также заполним нулями
data['balcony'] = data['balcony'].astype('int') #заменим float на int

#data['days_exposition'] = data['days_exposition'].fillna(0).astype('int') #заменим float на int

data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%d') #заменим first_day_exposition с object в формат даты, но без времени

#data['floors_total'] = data['floors_total'].fillna('0') #заполним пропуски 0
#data['floors_total'] = data['floors_total'].astype('int')  #заменим float на int
data[data['floors_total'].isna()]

data['last_price'] = data['last_price'].astype('int') #заменим float на int

#посмотрим что получилось
data.head(20)
#data.isna().sum()
#print(data['ceiling_height'].unique())

#остались пропуски Nan в столбцах parks_nearest,airports_nearest,parks_around3000
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000      108.00           2019-03-07      3
# 1              7     3350000       40.40           2018-12-04      1
# 2             10     5196000       56.00           2015-08-20      2
# 3              0    64900000      159.00           2015-07-24      3
# 4              2    10000000      100.00           2018-06-19      2
# 5             10     2890000       30.40           2018-09-10      1
# 6              6     3700000       37.30           2017-11-02      1
# 7              5     7915000       71.60           2019-04-18      2
# 8             20     2900000       33.16           2018-05-23      1
# 9             18     5400000       61.00           2017-02-26      3
# 10             5     5050000       39.60           2017-11-16      1
# 11             9     3300000       44.00           2018-08-27      2
# 12            10     3890000       54.00           2016-06-30      2
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# 1.1. Не совсем корректно заменять пропуски в ceiling_height на среднее значение. В этой колонке отсутствует около 38% данных. Это очень много, и сложно найти веские причины для таких радикальных трансформаций. На этом шаге можно попробовать заполнить медианой, так как она более устойчива к выбросам. Можно попробовать заполнить модой или медианой, или разбить данные на группы и заполнять пропуски средней мерой по группе, но в любом случае, нужно иметь в виду риски искажения данных.
#
# Хочу посоветовать тебе статью, которая рассматривает разные способы обработки пропусков, выделяет их плюсы и минусы, думаю, тебе может быть интересно: https://loginom.ru/blog/missing
#
#
# 1.2. Также ты верно пишешь, что в данных есть значения потолка равное 100 метров ( есть еще 1 метр) - затем исключаешь часть нереальных цифр 🙌, но 1 м и 100 м так и остались в наших данных( Здесь можно использовать метод query и удалить значения меньше или больше заданного числа:
#
#     data.drop(index=data.query('ceiling_height < 2.3').index,inplace=True)
#
#
# **Обращаю внимание на то, что если проводить чистку данных по столбцу с пропусками, то это может привести к удалению из датасета всех строк с пропусками в этом столбце. Поэтому важно заполнить пустые значения в колонках перед удалением аномалий в них.**
#
#
# 2. Для удобства приведу текст задания:
#         Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты. Например, «поселок Рябово» и «поселок городского типа Рябово», «поселок Тельмана» и «посёлок Тельмана» — это обозначения одних и тех же населённых пунктов. Вы можете заменить названия в существующем столбце или создать новый с названиями без дубликатов.
#
#
#  Пожалуйста, выполни обработку неявных дубликатов в locality_name.
#
#
# 3. Снова приведу пункт текст из ТЗ (по обработке аномалий):
#
#
#     Найдите и устраните редкие и выбивающиеся значения. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах.
#
#   Согласно последнему предложению необходимо исследовать и обработать аномалии не только в ceiling_height, living и kitchen_area, но и в других колонках, сделать этого можно с помощью построения боксплота или гистограмм. Посмотреть максимальные и минимальные значения можно при помощи метода describe.
#
#   Например,можно исключить такие значения, которые могут явно свидетельствовать об ошибке и их невозможно обработать. Стоит посмотреть выбросы по общей площади и цене и очистить данные от них. Как часто встречаются квартиры площадью больше 400/600/800 м? Можно ли очистить данные по какому-либо из этих значений?
#
#
#  Или можно  подойти к обработки выбросов "математически" и использовать метод IQR (почти то же самое, что и боксплоты, только метод дает возможность опредилить границы выбросов более точно) Оставлю несколько ссылок по работе с выбросами:
#
# https://pythobyte.com/detection-removal-outliers-in-python-adaa857e/
#
# https://towardsdatascience.com/why-1-5-in-iqr-method-of-outlier-detection-5d07fdc82097
#
# https://www.machinelearningmastery.ru/5-ways-to-detect-outliers-that-every-data-scientist-should-know-python-code-70a54335a623/
#
# https://proglib.io/p/moem-dataset-rukovodstvo-po-ochistke-dannyh-v-python-2020-03-27
#
#
# Также 3амечу, что в целом по датасету ***удаление 10% данных и менее - считается приемлемым уровнем при работе с очисткой данных***.
# На данном этапе необходимо отслеживать это.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Celling_floor посчитал медианной и вставил в пропуски.По Вашему коду для удаления аномальных значений у меня не получилось сделать(я сделал след образом, для значений больше 20 поделил их на 10</b>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# 1. По поводу текущей обработки Celling_floor  - согласна🙌
#
# 2. Теперь осталось обработать аномальные - крайние значения (выбросы). Для чего этого необходимо сделать? В целом наличие аномалий может манипулировать средним и основными статистиками, и , например, в нашем проекте стоит задача посмотреть на среднюю квартиру- средние потолки, площади и прочее, нам важно понять типичное значение, а с наличием аномалий эта типичность может быть сдвинута. Но в общем следует придерживаться здравого смысла, внимательно смотреть на данные и исключать аномалии при необходимости/ исходя из смысла поставленной задачи.
#
#
# Ниже выведены основные ключевые статистики по всему датасету - обрати внимание на минимальные/максимальные значения по потолку и по площади - кажется, что это нереальные значения, также обрати внимание на крайние значения по общей цене.
# Для исследования аномалий, помимо вывода ключевых статистик, будет полезно построить боксплоты по параметрам и на них оценить наличие выбросов.
#
#
# 3. Возможно код из предыдущего примера не отрабатывает из-за использования разных сред - в юпитер хаб он выполняется (Оставила код ниже - это просто пример и при самостоятельной работе его стоит удалить). Можно попробовать другим способом исключить  часть значений, например, использовать пандас нотацию:
#
#
#     data=data[data['total_area']>12]
#
#
#  или по другому применить метод query:
#
#     data=data.query('total_area > 12 and total_area < 900')
#
#
# ***Обращаю внимание на то, что если проводить чистку данных по столбцу с пропусками, то  это  может привести к удалению из датасета всех строк с пропусками в этом столбце. Поэтому важно заполнить пустые значения в колонках перед удалением аномалий в них.***

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента №2<a class="tocSkip"></h2>
#
# <b>Юля привет, спасибо за помощь с потолками. По твоему совету преобразовал написанный тобой код к своему решению, помоему все получилось. Посмотри пожалуйста
#
#  data=data.query('ceiling_height > 2.3 and ceiling_height < 2.7')
#
#   судя по дескрайбу, аномалий не вижу</b>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера #3 <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# 1. Действительно, код теперь отрабатывает 🤗 Только обрати внимание, что количество строк в датасете после такой обработки составляет 16811 строк, против 23699 изначальных. Мы теряем данных больше допустимого порогового уровня в 10%😔 В проекте фигурирует недвижимость Санкт-Петербурга, а как известно там довольно много квартир в домах дореволюционной постройки, и высота потолков в них может достигать даже 5 метров ( об этом говорят открытые источники 🙃) Поэтому стоит изменить максимальное значение потолка с 2,7 на большее, но приемлемое на твой взгляд.
#
#
# 2. Помимо потолков, нам необходимо исследовать аномалии в других параметрах. Как писала выше, минимально достаточно посмотреть общую площадь и цену недвижимости. В идеальном варианте следует исследовать все параметры. Минимальная площадь недвижимости составляет 12 метров. Насколько это похоже на правду? Стоит ли исключить такое значение?
#
# Пожалуйста, проведи исследование аномалий хотя бы по параметрам цены и площади. При необходимости обработай, исключи выбросы и напиши краткий вывод. На этом проект будет завершен.🤗

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента №2<a class="tocSkip"></h2>
#
# <b>Потолки сделал до 5 м. </b>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #4 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# 🙌

# %%
data=data.query('total_area > 24.0 and total_area < 631.0')

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента №2<a class="tocSkip"></h2>
#
# <b>Юля, посмотрел открытые источники, в них сказано, что минимальная площадь многоквартирного дома в СПБ 24 кв.м и макс 631 кв.м. Забил код согласно этим условиям, дескрайб и график показывают данные числа. </b>

# %%
data=data.query('last_price > 1.5e+6 and last_price < 2.56e+8')

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента №2<a class="tocSkip"></h2>
#
# <b>Из открытых источников нашел, что при хорошем везении можно купить 1.5 млн руб квартиру, а самая дорогая 256 млн.рублей. Согласно этой информации скорректировал данные. Извини, что они в экспоненте, не знаю как в вещественное перевести тут. </b>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #4 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Продуктивная работа🙌 Аномалии по наиболее важным параметрам обработаны 🤗
#
# Простой способ избавить от е-формата чисел при анализе данного столбца - перевести значения в колонке last_price из руб в млн руб. Для этого значения в колонке last_price нужно разделить на 1 000 000.

# %%
#КОД РЕВЬЮЕРА
data.describe()
#data.info()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  22824.000000  2.282400e+04  22824.000000  22824.000000    22824.000000
# mean       9.918332  6.596578e+06     60.979846      2.090519        2.698829
# std        5.698687  8.209360e+06     34.625147      1.077487        0.216763
# min        0.000000  1.510000e+06     24.050000      0.000000        2.340000
# 25%        6.000000  3.550000e+06     40.600000      1.000000        2.600000
# 50%       10.000000  4.750000e+06     53.000000      2.000000        2.650000
# 75%       14.000000  6.900000e+06     70.012500      3.000000        2.700000
# max       50.000000  2.450000e+08    590.000000     19.000000        4.900000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  22741.000000  21059.000000  22824.000000  20783.000000  22824.000000
# mean      10.846049     34.744875      5.977480     10.662114      0.598318
# ...

# %%
#КОД РЕВЬЮЕРА
#data.drop(index=data.query('ceiling_height < 2.3').index,inplace=True)

# %%
#КОД РЕВЬЮЕРА
#data.describe()

# %%
#Изучим уникальные значения в столбце с названиями и устраним неявные дубликаты.
#изучим locality_name
data['locality_name'].sort_values().unique()
# Out:
# array(['Волосово', 'Волхов', 'Всеволожск', 'Выборг', 'Высоцк', 'Гатчина',
#        'Зеленогорск', 'Ивангород', 'Каменногорск', 'Кингисепп', 'Кириши',
#        'Кировск', 'Колпино', 'Коммунар', 'Красное Село', 'Кронштадт',
#        'Кудрово', 'Лодейное Поле', 'Ломоносов', 'Луга', 'Любань',
#        'Мурино', 'Никольское', 'Новая Ладога', 'Отрадное', 'Павловск',
#        'Петергоф', 'Пикалёво', 'Подпорожье', 'Приморск', 'Приозерск',
#        'Пушкин', 'Санкт-Петербург', 'Светогорск', 'Сертолово',
#        'Сестрорецк', 'Сланцы', 'Сосновый Бор', 'Сясьстрой', 'Тихвин',
#        'Тосно', 'Шлиссельбург', 'городской поселок Большая Ижора',
#        'городской поселок Янино-1', 'городской посёлок Будогощь',
#        'городской посёлок Виллози', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
#        'городской посёлок Свирьстрой', 'городской посёлок Советский',
# ...

# %%
# изменим слово поселок на посёлок через replace
data['locality_name'] = data['locality_name'].str.replace('поселок','посёлок')

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Волосово', 'Волхов', 'Всеволожск', 'Выборг', 'Высоцк', 'Гатчина',
#        'Зеленогорск', 'Ивангород', 'Каменногорск', 'Кингисепп', 'Кириши',
#        'Кировск', 'Колпино', 'Коммунар', 'Красное Село', 'Кронштадт',
#        'Кудрово', 'Лодейное Поле', 'Ломоносов', 'Луга', 'Любань',
#        'Мурино', 'Никольское', 'Новая Ладога', 'Отрадное', 'Павловск',
#        'Петергоф', 'Пикалёво', 'Подпорожье', 'Приморск', 'Приозерск',
#        'Пушкин', 'Санкт-Петербург', 'Светогорск', 'Сертолово',
#        'Сестрорецк', 'Сланцы', 'Сосновый Бор', 'Сясьстрой', 'Тихвин',
#        'Тосно', 'Шлиссельбург', 'городской посёлок Большая Ижора',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Мга', 'городской посёлок Назия',
#        'городской посёлок Новоселье', 'городской посёлок Павлово',
#        'городской посёлок Рощино', 'городской посёлок Свирьстрой',
#        'городской посёлок Советский', 'городской посёлок Фёдоровское',
# ...

# %%
# Через replace приведём к посёлку 
data = data.replace({'locality_name':{'Никольское': 'село Никольское', 'городской посёлок Советский': 'посёлок городского типа Советский', 'городской посёлок Большая Ижора': 'посёлок городского типа Большая Ижора', 'городской посёлок Лесогорский': 'посёлок городского типа Лесогорский', 'посёлок Рябово': 'посёлок городского типа Рябово', 'городской посёлок Мга': 'посёлок городского типа Мга', 'городской посёлок Павлово': 'посёлок городского типа Павлово', 'городской посёлок Назия': 'посёлок городского типа Назия', 'коттеджный посёлок Лесное': 'посёлок Лесное', 'Мурино': 'посёлок Мурино', 'Любань': 'посёлок Любань', 'городской посёлок Рощино': 'посёлок городского типа Рощино', 'деревня Кудрово': 'Кудрово'}})

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Волосово', 'Волхов', 'Всеволожск', 'Выборг', 'Высоцк', 'Гатчина',
#        'Зеленогорск', 'Ивангород', 'Каменногорск', 'Кингисепп', 'Кириши',
#        'Кировск', 'Колпино', 'Коммунар', 'Красное Село', 'Кронштадт',
#        'Кудрово', 'Лодейное Поле', 'Ломоносов', 'Луга', 'Новая Ладога',
#        'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво', 'Подпорожье',
#        'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург', 'Светогорск',
#        'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор', 'Сясьстрой',
#        'Тихвин', 'Тосно', 'Шлиссельбург', 'городской посёлок Будогощь',
#        'городской посёлок Виллози', 'городской посёлок Новоселье',
#        'городской посёлок Свирьстрой', 'городской посёлок Фёдоровское',
#        'городской посёлок Янино-1', 'деревня Агалатово', 'деревня Аро',
#        'деревня Батово', 'деревня Бегуницы', 'деревня Белогорка',
#        'деревня Большая Вруда', 'деревня Большие Колпаны',
# ...

# %%
#удалим строки без города, чтоб не мешались в выборке
data = data.dropna(subset=['locality_name'])

# %%
# проверим, что пропуски удалены.
data['locality_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
#  Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты. Например, «поселок Рябово» и «поселок городского типа Рябово», «поселок Тельмана» и «посёлок Тельмана» — это обозначения одних и тех же населённых пунктов. Вы можете заменить названия в существующем столбце или создать новый с названиями без дубликатов.
#
#
#  Сделал

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Здорово, что выполнена обработка неявных дубликатов в locality_name.👍👍👍

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
#Добавим в таблицу новые столбцы со следующими параметрами: цена одного квадратного метра, день недели публикации объявления, месяц публикации объявления
#год публикации объявления, тип этажа квартиры, расстояние до центра города в километрах

data['price_square_meter'] = data['last_price'] / data['total_area']#Посчитаем цену одного квадратного метра
data['price_square_meter'] = round(data['price_square_meter'], 2) #для удобства оставим 2 знака после запятой
#print(data['price_square_meter'].head(10)) #посмотрим, что получилось

data['day_exposition'] = data['first_day_exposition'].dt.weekday #день недели публикации объявления
data['month_exposition'] = data['first_day_exposition'].dt.month #месяц публикации объявления
data['year_exposition'] = data['first_day_exposition'].dt.year #год публикации объявления

#data.head(10)#посмотрим, что получилось

def type_floor(row): #на основании укажем тип этажа квартиры
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    elif 1 < floor < floors_total:
        return 'другой'
    
data['type_floor'] = data.apply(type_floor, axis = 1)


data['cityCenters_nearest_km'] = round(data['cityCenters_nearest'] / 1000) #перевели метры в км, и округлили

data.head(10)
#print(data['type_floor'].unique())
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
# 5            10     2890000       30.40           2018-09-10      1
# 6             6     3700000       37.30           2017-11-02      1
# 7             5     7915000       71.60           2019-04-18      2
# 8            20     2900000       33.16           2018-05-23      1
# 9            18     5400000       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8        false  ...
# 1            2.65          11.0        18.60      1        false  ...
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Основные моменты на этом шаге анализа учтены 🤗

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %%
#проведем исследовательский анализ данных и изучим параметры объектов 

#проведем исследование по общей площади и построим диаграмму
data.plot(y = 'total_area', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,500))
data['total_area'].describe() 

plt.title('Общая площадь')
plt.xlabel('площадь')
plt.ylabel('количество объявлений.')
#рассмотрим числовое описание данных для колонки. В целом данные представлены в приемлемом виде,
#большинство квартир площадью 60 квадратов, есть выбросы но их очень мало.
# Out:
# Text(0, 0.5, 'количество объявлений.')

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# При использовании визуализации в проекте, стоит уделить внимание ее оформлению: ко всем графикам в проекте важно добавлять заголовки и подписи осей. Пожалуйста, скорректируй графики во всем проекте:)
#
#
# Полезные ссылки:
#
# https://www.python-graph-gallery.com/4-add-title-and-axis-label
#
# https://www.kite.com/python/answers/how-to-add-axis-labels-to-a-plot-in-matplotlib-in-python
#
# https://stackoverflow.com/questions/12444716/how-do-i-set-the-figure-title-and-axes-labels-font-size-in-matplotlib

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Хорошо, что соблюдена данная рекомендация - надлежащее оформление визуализации это "хороший тон" в работе аналитика.

# %%
#проведем исследование по жилой площади и построим диаграмму
data.plot(y = 'living_area', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,100))
data['living_area'].describe()

plt.title('Жилая площадь')
plt.xlabel('площадь')
plt.ylabel('количество объявлений.')
plt.show()
#большинство квартир с жилой площадью равняется 34 квадратов

# %%
#проведем исследование по площади кухни и построим диаграмму
data.plot(y = 'kitchen_area', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,50))
data['kitchen_area'].describe()

plt.title('Площадь кухни')
plt.xlabel('площадь кухни')
plt.ylabel('количество объявлений.')
plt.show()
#большинство квартир с площадью кухни 10 квадратов

# %%
#проведем исследование по цене объекта и построим диаграмму
data.plot(y = 'last_price', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,18000000))
data['last_price'].describe()

plt.title('Цена объекта')
plt.xlabel('Цена')
plt.ylabel('количество объявлений.')
plt.show()
#цифры выводятся Экспоненциальной записи

# %%
#проведем исследование высоты потолков и построим диаграмму
data.plot(y = 'ceiling_height', kind = 'hist', bins = 30, range = (2,10), grid=True, figsize = (10,5))
data['ceiling_height'].describe()

plt.title('Высота потолка')
plt.xlabel('высота,м')
plt.ylabel('количество объявлений.')
plt.show()
#большинство потолков до 3 м.

# %%
#проведем исследование этажа квартир и построим диаграмму
data.plot(y = 'floor', kind = 'hist', bins = 30, range = (2,20), grid=True, figsize = (10,5))
data['floor'].describe()

plt.title('Этаж продающихся квартир')
plt.xlabel('этаж')
plt.ylabel('количество объявлений.')
plt.show()
#самое большое количество квартир до 5 этажа

# %%
#проведем исследование количества этажей и построим диаграмму
data.plot(y = 'floors_total', kind = 'hist', bins = 30, range = (2,30), grid=True, figsize = (10,5))
data['floors_total'].describe()

plt.title('Этажность домов продающихся квартир')
plt.xlabel('этаж')
plt.ylabel('количество объявлений.')
plt.show()
#самое большое количество домов с квартирами являются 5 этажные и 9-10

# %%
#проведем исследование количества этажей и построим диаграмму
data['type_floor'].value_counts().plot.bar(figsize=(10, 5), ec='black', legend=True)
plt.title('количество объявлений по этажам')
plt.xlabel('этаж')
plt.ylabel('количество объявлений.')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Также на этом шаге необходимо построить гистограмму для типа этажа (type floor) - об этом было сказано в задании.
#
#
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# Сделал

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# +

# %%
#проведем исследование удаленности от центра города и построим диаграмму
data.plot(y = 'cityCenters_nearest', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,100000))
data['cityCenters_nearest'].describe()

plt.title('Удаленность квартир от центра города')
plt.xlabel('удаленность от центра,м')
plt.ylabel('количество объявлений.')
plt.show()
#основная часть квартир находится в радиусе 20 000 метров.

# %%
#проведем исследование удаленности от аэропорта и построим диаграмму
data.plot(y = 'airports_nearest', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,100000))
data['airports_nearest'].describe()

plt.title('Удаленность квартир от аэропорта')
plt.xlabel('удаленность от аэропорта,м.')
plt.ylabel('количество объявлений.')
plt.show()
#Большая часть домов находится в диапазоне от 10 000 до 40 000 от аэропорта

# %%
#проведем исследование удаленности от парка и построим диаграмму
data.plot(y = 'parks_nearest', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,10000))
data['parks_nearest'].describe()

plt.title('Удаленность квартир от парка')
plt.xlabel('удаленность от парка,м')
plt.ylabel('количество объявлений.')
plt.show()
#в основном все квартиры находятся в 500 метрах от парков

# %%
#проведем исследование день публикации объявления и построим диаграмму
data.plot(y = 'day_exposition', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (0,6))
data['day_exposition'].describe()

plt.title('Объявления по дням')
plt.xlabel('день публикации объявления')
plt.ylabel('количество объявлений.')
plt.show()
#в целом идет равномерное распределение между буднями днями. Но наибольшее количество объявлений было в четверг. Наименьшие показатели в выходные

# %%
#проведем исследование месяц публикации объявления и построим диаграмму
data.plot(y = 'month_exposition', kind = 'hist', bins = 100, grid=True, figsize = (10,5), range = (1,13))
data['month_exposition'].describe()

plt.title('Объявления по месяцам')
plt.xlabel('месяц публикации объявления')
plt.ylabel('количество объявлений.')
plt.show()
#наибольшее количество объявлений приходится на февраль, наименьшее на май

#в общем можно сказать, что предложений очень много на рынке, есть большое количество критериев которые могут удовлетворить любого
#клиента и подобрать то решение, которое ему будет по душе и по корману.Но в целом прослеживается паралель между такими критериями
#удаленность от центра, от порка, общая площадь,количество комнат, и тд. все эти параметры влияют на цену.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Ранее была введена заглушка равная 0 для пропусков в days_exposition. При анализе основынх ключевых статистик ее стоит отфильтровывать, так как наличие таких значений ведет к искажению результатов.
#
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
#  Заглушку убрал

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера #2 <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Сергей, в коде ниже заглушка не фильтруется, но на этапе предобработки данных она была введена - оставила выше комментарий об этом. Необходимо еще раз проверить этот момент~
#
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
#  Убрал, график перестроился,но на ответ это не повлияло. Среднее значение продажи квартиры одно полугодие

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #3<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# 👌

# %%
#Изучим, как быстро продавались квартиры.
data['days_exposition'].describe().to_frame() #среднее значение 156 дней , а максимальное 4 года
data['days_exposition'].median() #медианное значение 74 дня
data['days_exposition'].hist(bins=70, figsize=(10,5), ec='black')
plt.show()
#самые большие продажи в течении 100 дней, есть квартиры которые продавались более года, и даже более

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# 1. Сергей, ты проделал детальную работу на этом шаге!👍👍👍 Выводы из этого раздела можно использовать в финальном подведении итогов.
#
# 2. Убрать техническую строчку <AxesSubplot:> можно с помощью метода `plt.show()` или `;` (у тебя есть эта проблема на графике выше).

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
#  Спасибо за подсказку, сделал

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# 🙌

# %%
#сейчас изучим Какие факторы больше всего влияют на общую (полную) стоимость объекта.

#Изучим, зависит ли цена от общей площади
pivot_table_total_area = data.pivot_table(index = 'total_area', values = 'price_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_total_area.columns = ['mean', 'count', 'median']
pivot_table_total_area.plot(y = 'median', style = 'o', figsize=(10,5))

pivot_table_total_area.sort_values('median', ascending = False)

data['total_area'].corr(data['price_square_meter'])

plt.title('зависимость цены от общей площади')
plt.xlabel('кв.м.квартиры')
plt.ylabel('цена кв.метра.')
plt.show()
#корреляция 0.3, чем выше площадь, тем выше стоимость

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Коэффициенты корреляции можно вывести в единой корреляционной таблице или в качестве альтернативы использовать график типа `heatmap`
#
# https://datatofish.com/correlation-matrix-pandas/ (построение корреляционной матрицы с помощью Python)
#
#
# https://stackoverflow.com/questions/29432629/plot-correlation-matrix-using-pandas (полезный тред на Stackoverflow, очень полезный ресурс для кодеров, советую, с помощью него можно решить практически все проблемы, которые возникают у тебя при работе с кодом)
#
# https://likegeeks.com/python-correlation-matrix/ (еще один туториал)
#
# Другой вариант - график pairplot библиотеки seaborn.
#
# Подробнее:
#
# https://www.machinelearningmastery.ru/visualizing-data-with-pair-plots-in-python-f228cf529166/
#
# https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
#  Спасибо за совет и за литературу!

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# 🤗

# %%
#Изучим, зависит ли цена от жилой площади
pivot_table_living_area = data.pivot_table(index = 'living_area', values = 'price_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_living_area.columns = ['mean', 'count', 'median']
pivot_table_living_area.plot(y = 'median', style = 'o', figsize=(10,5))

pivot_table_total_area.sort_values('median', ascending = False)

data['living_area'].corr(data['price_square_meter'])

plt.title('зависимость цены от площади жилого помещения')
plt.xlabel('кв.м.жилого помещения')
plt.ylabel('цена кв.метра.')
plt.show()
#корреляция 0.2, здесь также можно сказать, что чем больше жилая площадь, тем больше цена.

# %%
#Изучим, зависит ли цена от площади кухни
pivot_table_kitchen_area = data.pivot_table(index = 'kitchen_area', values = 'price_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_kitchen_area.columns = ['mean', 'count', 'median']
pivot_table_kitchen_area.plot(y = 'median', style = 'o', figsize=(10,5))

pivot_table_total_area.sort_values('median', ascending = False)

data['kitchen_area'].corr(data['price_square_meter'])

plt.title('зависимость цены от площади кухни')
plt.xlabel('кв.м.кухни')
plt.ylabel('цена кв.метра.')
plt.show()
#корреляция 0.4, здесь также можно сказать, что чем больше жилая площадь, тем больше цена. Хоть корреляция по отношению к другим
#выше чем в жилой площади и общей, но корреляция все ровно остается низкой.

# %%
#Изучим, зависит ли цена от количества комнат
pivot_table_rooms = data.pivot_table(index = 'rooms', values = 'price_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_rooms.columns = ['mean', 'count', 'median']
pivot_table_rooms.query('count > 50').plot(y = 'median', style = '-o', figsize=(10,5))

pivot_table_rooms.query('count > 50').sort_values('median', ascending = False)

data['rooms'].corr(data['price_square_meter'])

plt.title('зависимость от количества комнат')
plt.xlabel('комнаты')
plt.ylabel('цена кв.метра.')
plt.show()
# цена идет на снижение к 3-комнаным квартирам, и снова поднимается

# %%
#Изучим, зависит ли цена от этажа, на котором расположена квартира (первый, последний, другой);
pivot_table_type_floor = data.query('type_floor != "0"').pivot_table(index = 'type_floor', values = 'price_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_type_floor.columns = ['mean', 'count', 'median']
pivot_table_type_floor.plot(y = 'median', figsize=(10,5))
pivot_table_type_floor

plt.title('зависимость цены от этажа')
plt.xlabel('этаж')
plt.ylabel('цена кв.метра.')
plt.show()
#согласно графику, цена на первом этаже меньше всех, далее на 10% выше цена на послднем этаже, и самые дорогие квартиры между первым и последним этажем.

# %%
#Изучим, зависит ли цена от даты размещения (день недели)
pivot_table_day_exposition = data.pivot_table(index = 'day_exposition', values = 'price_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_day_exposition.columns = ['mean', 'count', 'median']
pivot_table_day_exposition.plot(y = 'median', figsize=(10,5))

pivot_table_day_exposition.sort_values('median', ascending = False)

plt.title('зависимость размещения от дня недели')
plt.xlabel('день недели')
plt.ylabel('цена кв.метра.')
#Самые высокие цены на квартиры после выходных, а именно в будние дни, кажется люди которые выставляют квартиры после выходных более
#подготовлены, так-как могут потратить выходные на алалитику рынка, как мы видим из графика самые низкие цены к концу рабочей недели
#вероятно это связано с тем, что к этому времени люди находятся в состоянии усталости и менее опираются на аналитику и расширенному анализу рынка
# Out:
# Text(0, 0.5, 'цена кв.метра.')

# %%
#Изучим, зависит ли цена от даты размещения (месяц)
pivot_table_month_exposition = data.pivot_table(index = 'month_exposition', values = 'price_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_month_exposition.columns = ['mean', 'count', 'median']
pivot_table_month_exposition.plot(y = 'median', figsize=(10,5))

pivot_table_month_exposition.sort_values('median', ascending = False)

plt.title('зависимость от месяца размещения')
plt.xlabel('месяц')
plt.ylabel('цена кв.метра.')
plt.show()
#по графику мы видим, что он сезонный, например зимой перед новогодними праздниками спрос снижается, ближе к весне он стремится к пику.
#летом в сезон отпусков, когда все люди отдыхают и тратят свои деньги от отдых, спрос меньше всего. К началу осени он набирает обороты.

# %%
#Изучим, зависит ли цена от даты размещения (год)
pivot_table_year_exposition = data.pivot_table(index = 'year_exposition', values = 'price_square_meter', aggfunc = ['mean', 'count', 'median'])
pivot_table_year_exposition.columns = ['mean', 'count', 'median']
pivot_table_year_exposition.plot(y = 'median', figsize=(10,5))

pivot_table_year_exposition.sort_values('median', ascending = False)

plt.title('зависимость от года размещения')
plt.xlabel('год')
plt.ylabel('цена кв.метра.')
plt.show()
#по графику мы видим, что с 2014 года идет стремительное снижение до 2016 года, это связано с Валютным кризисом 2014 года в России,
#после 2016 года ситуация начала выравниваться и в 2017 мы видим увеличение спроса, к 2019 году рынок почти вернулся к значениям 2014 года

#в целом если рассмотреть графики, можно прийти к выводу что исследование показывает, что на спрос и предложение на рынке недвижимости воздействует целый ряд факторов
#не только по параметрам инфраструктуры, но и экономическая ситуация в стране

# %%
#Изучим, годовую динамику обшщей цены
pivot_table_year_exposition_last_price = data.pivot_table(index = 'year_exposition', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_year_exposition_last_price.columns = ['mean', 'count', 'median']
pivot_table_year_exposition_last_price.plot(y = 'median', figsize=(10,5))

pivot_table_year_exposition.sort_values('median', ascending = False)

plt.title('годовая динамика общей цены')
plt.xlabel('год')
plt.ylabel('цена квартиры.')
plt.show()

# %%
#Изучим общую площадь
pivot_table_total_area_year = data.pivot_table(index = 'year_exposition', values = 'total_area', aggfunc = ['mean', 'count', 'median'])
pivot_table_total_area_year.columns = ['mean', 'count', 'median']
pivot_table_total_area_year.plot(y = 'median', figsize=(10,5))

pivot_table_total_area_year.sort_values('median', ascending = False)

plt.title('годовая динамика площади квартир')
plt.xlabel('год')
plt.ylabel('площадь квартиры.')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Давай рассмотрим еще годовую динамику общей цены и годовую динамику площади продаваемых квартир. И потом расширим выводы, т.к., возможно, менялась не столько цена, сколько площадь продаваемых квартир.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Из годовой динамики общей цены и годовой динамики площади, мы видим, что с 2014 года, цена на квартиры начинает снижаться, это связано с спросом, так-как был маленький спрос, люди начали снижать цену продажи. Что касается годовой динамики площади квартир, то здесь мы также видим спад в продажах. Вероятно квартиры за 50+ квадратов были слишком дорогие для рынка, и их не покупали.:</b>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Согласна с выводом - площадь продаваемых квартир снижается~

# %%
#Изучим, среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.
cityname = data['locality_name'].value_counts().index.tolist()[:10]
price_square = [data[data['locality_name'] == city]['price_square_meter'].median().round(2) for city in cityname]
price_home = [data[data['locality_name'] == city]['last_price'].median() for city in cityname]
frame = {'Город': cityname, 'Цена квадратного метра': price_square, 'Цена квартиры': price_home}
df = pd.DataFrame(frame).sort_values(by='Цена квадратного метра', ascending=False)
df

#Самая дорогая недвижимость в Санкт-Петербурге, самая дешевая в Выборге. Обусловлено тем, что Выборг находится в 140 от областного центра.
# Out:
#                Город  Цена квадратного метра  Цена квартиры
# 0    Санкт-Петербург               104651.16      5512500.0
# 5             Пушкин                99993.59      5187319.0
# 2            Кудрово                95185.19      3940000.0
# 7  посёлок Парголово                91780.22      4115000.0
# 1     посёлок Мурино                85145.66      3450000.0
# 3     посёлок Шушары                76666.67      3990000.0
# 6            Колпино                74722.22      3600000.0
# 8            Гатчина                67944.25      3100000.0
# 4         Всеволожск                65789.47      3500000.0
# 9             Выборг                59090.91      2980000.0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Для максимального перфекционизма можно дополнить вывод визуализацией- столбчатого или линейного графика будет достаточно.

# %%
#Изучим и выделим квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислим среднюю цену каждого километра. 
#Опишем, как стоимость объектов зависит от расстояния до центра города.

#data = data.query('locality_name == "Санкт-Петербург"')
data['cityCenters_nearest_km'] = data.loc[:, 'cityCenters_nearest'] / 1000 #добавляем столбец с км
data['cityCenters_nearest_km'] = data['cityCenters_nearest_km'].round() #округялем

data['spb_cityCenters_nearest_km'] = data['last_price'] / data['total_area'] #средняя цена кв.м

#посчитаем среднюю столбца spb_house['spb_cityCenters_nearest_km']
data['spb_cityCenters_nearest_km_avg'] = data['spb_cityCenters_nearest_km'].mean()

#посчитаем ср.цену для каждого км.
data['avg_price_for_km_spb'] = data['spb_cityCenters_nearest_km_avg'] / data['cityCenters_nearest_km']

data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            10     5196000        56.0           2015-08-20      2
# 3             0    64900000       159.0           2015-07-24      3
# 4             2    10000000       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8        false  ...
# 1            2.65          11.0         18.6      1        false  ...
# 2            2.65           5.0         34.3      4        false  ...
# 3            2.65          14.0          NaN      9        false  ...
# 4            3.03          14.0         32.0     13        false  ...
#
#    days_exposition  price_square_meter  day_exposition  month_exposition  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Упс, код падает с ошибкой: name 'spb_house' is not defined. Причина в первой строке: spb_house = spb_house.query('locality_name == "Санкт-Петербург"') . Ты фильтруешь даннные в датасете spb_house, но он еще не создан 🙃
#
# Пожалуйста, поправь свое решение~
#
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Вижу ошибку, спасибо. Заменил переменную, не пойму почему до отправки на ревью она показывала корректные результаты. Дважды проверил, все работало ))):</b>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# В текущей версии тоже работает~

# %%
#Изучим и выделим квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислим среднюю цену каждого километра. 
#Опишем, как стоимость объектов зависит от расстояния до центра города.

data.plot(x='cityCenters_nearest_km', y='avg_price_for_km_spb', kind='scatter', figsize=(10, 5), grid=True)
plt.title('Стоимость объекта от центра')
plt.xlabel('цена,руб')
plt.ylabel('км от центра.')
#на графике видно, что удаленность от центра влияет на стоимость метра жилья в СПБ, в первых 5 км от центра стоиомость резко падает
#с 120 000 до 20 000 рублей, после 5 км она плавно идет на снижение. Самые дорогие квартиры в первых 5 км от центра
# Out:
# Text(0, 0.5, 'км от центра.')

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Получив архив объявлений за несколько лет о продаже квартир в Санкт-Петербурге и соседних населённых пунктах мы приступили к анализу полученых материалов. Обработали пропущенные значения, поменяли типы данных где это было необходимо. Доработали архив, дополнив его данными такими как (цена одного квадратного метра, тип этажа квартиры, день недели публикации, растояние до центра города и тд.
#
# На основе собранных данных, мы начали проводить исследовательский анализ даннных.Изучив уникальные значения в столбце с названиями населенных пунктов, мы столкнулись с дублированием записей, дубликаты были устранены, база приведена в порядок.
#
# Проанализировав большой массив данных, можем сказать, что большинство квартир выставленных на продажу имеют 60 кв.м общую площадь, 34 кв.м - жилую площадь, кухни 10 кв.м. Большинство квартир выставленных на продажу до 5-го этажа включительно. Самое большое количество домов с квартирами это 5 и 9-10 этажные дома. Большая часть квартир в архиве в 20 км. от центра, от аэрапорта львиная доля квартир находится от 10 до 40 км. Часто квартиры продаются до 500 метров от парков. Объявления публиковались больше в будни чем в выходные, наибольшее количество объявлений приходится на февраль, наименьшее на май. Самые большие продажи в течении 100 дней, есть квартиры которые продавались более года, и даже более. Проанализировав данные мы понимаем, что чем выше площадь, тем выше стоимость, корреляция от 0.3 до 0.4. Трехкомнатные квартиры стоят дешевле чем, 2-х и 4-х комнатные. Цена на первых этажах меньше на 10% чем на последнем и на 20% чем на остальных.
#
#
# Самые высокие цены на квартиры после выходных, а именно в будние дни, кажется люди которые выставляют квартиры после выходных болееподготовлены, так-как могут потратить выходные на алалитику рынка, как мы видим из графика самые низкие цены к концу рабочей недели вероятно это связано с тем, что к этому времени люди находятся в состоянии усталости и менее опираются на аналитику и расширенному анализу рынка.
#
# Установлено, что продажа квартир сезонна, например зимой перед новогодними праздниками спрос снижается, ближе к весне он стремится к пику летом в сезон отпусков, когда все люди отдыхают и тратят свои деньги от отдых, спрос меньше всего. К началу осени он набирает обороты.
#
#
# Мы видим, что с 2014 года идет стремительное снижение до 2016 года, это связано с Валютным кризисом 2014 года в России, после 2016 года ситуация начала выравниваться и в 2017 мы видим увеличение спроса, к 2019 году рынок почти вернулся к значениям 2014 года в целом если рассмотреть графики, можно прийти к выводу что исследование показывает, что на спрос и предложение на рынке недвижимости воздействует целый ряд факторов не только по параметрам инфраструктуры, но и экономическая ситуация в стране.
#
#
# Самая дорогая недвижимость в Санкт-Петербурге, самая дешевая в Выборге. Обусловлено тем, что Выборг находится в 140 от областного центра.
# Мы видим удаленность от центра влияет на стоимость метра жилья в СПБ, в первых 5 км от центра стоиомость резко падает с 120 000 до 20 000 рублей, после 5 км она плавно идет на снижение. Самые дорогие квартиры в первых 5 км от центра
#
# Из годовой динамики общей цены и годовой динамики площади, мы видим, что с 2014 года, цена на квартиры начинает снижаться, это связано с спросом, так-как был маленький спрос, люди начали снижать цену продажи. Что касается годовой динамики площади квартир, то здесь мы также видим спад в продажах. Вероятно квартиры за 50+ квадратов были слишком дорогие для рынка, и их не покупали.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# В аналитическом исследовании важно указывать понятный и развёрнутый вывод, ведь он раскрывает для заказчика всю твою проделанную работу и за что он платит деньги. Даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно. Ты молодец!

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Вывод дополнил:</b>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера #2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# 🙌

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Сергей, спасибо за твой проект! Тобою выполнен большой объем работы , все пункты работы соблюдены; оформление, комментарии и выводы представлены, ты большой молодец! Существует несколько важных моментов, которые можно было бы улучшить, рекомендации будут ниже в комментариях.
#
# **Отмечу отдельно положительные моменты проекта🙂**:
#
#
# * На разных шагах проекта ты предлагал очень интересные решения и методы для их реализации. Хорошая работа!
# * Ты активно использовал визуализацию, хорошо, что ты не избегаешь этого инструмента анализа.
#
#
# **На что стоит обратить внимание🤓**:
#
# * Важно доработать итоговый вывод на основании обновленного анализа.
# * Все выводы и комментарии к логике работы вынести в отдельные текстовые ячейки с типом markdown.
# * Построить общую гистограмму по датасету.
# * Скорректировать подход к обработке пропусков в ceiling_height.
# * Выполнить исследование и обработку аномалий в полном объеме.
# * Построить отдельную гистограмму для типа этажа.
# * Отфильтровать заглушку в days_exposition при анализе времени продажи недвижимости.
# * Доработать решение на этапе анализа зависимости цены от удаленности от центра в Санкт-Петербурге.
# * Оформление графиков.
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проверке #2**
#
# Сергей, благодарю за выполненные доработки! Ты продуктивно поработал, осталось совсем немного до завершения проекта:
#
# **Что осталось сделать🤓**:
#
# * Выполнить исследование и обработку аномалий в полном объеме.
# * Отфильтровать заглушку в days_exposition при анализе времени продажи недвижимости.
# * Остальные рекомендации ты найдешь в моих комментариях!
#
# **Желаю удачи и жду твой проект на финальное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проверке #3**
#
# Сергей, ты хорошо поработал над текущим проектом, осталось выполнить исследование и обработку аномалий и проект будет завершен 🤗.
#
# **Желаю удачи и ожидаю работу на финальное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проверке #4**
#
# Сергей, благодарю за сотрудничество🤝 На мой взгляд у нас получился конструктивный диалог и теперь работа над проектом завершена👍👍👍
#
#
# **Желаю удачи и успеха в освоение дальнейшей учебной программы!🤗**

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
