# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px; ">
# <b> Комментарий ревьюера</b>
#
# Привет! Меня зовут Светлана Носова, я буду проверять твой проект. Прошу прощения за задержку ревью 🙏 По техническим причинам не удавалось отправить работу.
#
#
# Если не против, давай общаться на «ты». Если тебе такой стиль общения не нравится, напиши об этом, будем на «вы».
#
# Сразу хочу обратить внимание на цветовую разметку:
#
#
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Зеленым с пометкой ✔️ отмечены отличные решения и идеи, которые можно и нужно использовать в будущем.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Желтым с пометкой ⚠️ отмечено то, что можно или нужно оптимизировать, в зависимости от контекста.</div>
#
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
#
# Красным с пометкой ❌ обозначены пропущенные пункты задания и ошибки, которые обязательно надо будет исправить, чтобы результаты были верные.</div>
#
# **Ответы на мои комментарии или доработки по моим рекомендациям попрошу выделить каким-нибудь цветом, кроме трех перечисленных.**
# Также я попрошу тебя **не менять и не передвигать мои комментарии**, чтобы при последующей проверке мне было проще ориентироваться.
#
# Кроме того, комментарии у меня обозначены как заголовки. Это сбивает содержание, но при последующей проверке я могу снять с них заголовок, если тебе так будет удобнее. При этом они удобны, поскольку ты сразу можешь перейти к ним.
#
# <hr>
#
# <font color= 'dodgerblue'>**По проекту:**</font> работа сделана очень хорошо, все оформлено аккуратно и понятно. Структура работы у тебя грамотная, код легко читается, много анализа и выводов. У меня остались некоторые вопросы, я все обозначила в комментариях. Там же я оставила рекомендации по улучшению проекта. Буду ждать работу на повторное ревью.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Светлана, привет! Спасибо, что проверила мою работу и дала экспертную оценку, буду стараться следовать всем твоим советам, для улучшения своего кода в будущем:</b>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 2</b>
#
# Тебе спасибо за такую хорошую работу и за корректировки. Я оставила новые комментарии с цифрой 2. Кое-где не был скорректирован период, там я оставила комментарии. Посмотри, пожалуйста. Если есть вопросы, задавай.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2<a class="tocSkip"></h2>
#
# <b>Светлана, привет! Спасибо за советы. Пользуясь случаем, хочу тебя поздравить с международным женским днем и пожелать тебе всего наилучшего!</b>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 3</b>
#
# Спасибо 😊
#
#
# Рада, что мои комментарии были полезны. Остался один мелкий недочет, который стоит исправить. Недочет этот довольно важный, потому что это одна из тех вещей, на которых мы учимся. Глянь, пожалуйста.
#
#
# Постараюсь побыстрее провести следующую итерацию.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 3<a class="tocSkip"></h2>
#
# <b>Светлана, привет! Постараюсь привести все к финальному виду), замучал тебя уже)</b>

# %% [markdown]
# <div style="border-radius: 15px; border: 3px solid indigo; padding: 15px;">
# <b> Комментарий ревьюера 4</b>
#
# Скорее я тебя :) Теперь все супер! Парочку новых комментариев оставила, но исправлять уже ничего не нужно. Проект я могу принять, поскольку вопросов больше нет. Желаю успехов в дальнейшем обучении :)
#
#
#
# </div>

# %% [markdown]
# # Описние проекта

# %% [markdown]
# **Мы работаем в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Нам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.Перед нами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и мы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы. В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков»**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Хорошо, что добавляешь краткое описание задачи. Это поможет быстро вспомнить, о чем проект, когда ты вернешься к нему.    Кроме того, так работа выглядит гораздо презентабельнее.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ⚠️</h2>
#
# В будущем рекомендую добавлять еще и содержание. Так в работе будет проще ориентироваться.
# </div>

# %% [markdown]
# ## Что необходимо будет сделать

# %% [markdown]
# ### Подготовьте данные
# ### Замените названия столбцов (приведите к нижнему регистру);
#
# ### Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
#
# ### Обработайте пропуски при необходимости:
# #### Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# #### Опишите причины, которые могли привести к пропускам;
# #### Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать
#
# ### Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %% [markdown]
# ## Проведём исследовательский анализ
# ### Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
#
# ### Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?**
#
# ### Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
#
# ### Не учитывайте в работе данные за предыдущие годы.
#
# ### Какие платформы лидируют по продажам, растут или падают?
#
# ### Выберите несколько потенциально прибыльных платформ.
#
# ### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
#
# ### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.
# ### Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
#
# ### Соотнесите выводы с продажами игр на других платформах.
#
# ### Посмотрите на общее распределение игр по жанрам.
#
# ### Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?.

# %% [markdown]
# ## Составим портрет пользователя каждого региона
# ### Определите для пользователя каждого региона (NA, EU, JP):
# ### Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# ### Самые популярные жанры (топ-5). Поясните разницу.
# ### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ⚠️</h2>
#
# Кстати, чтобы эти фразы не отображались в содержании (добавлю скриншот на всякий случай), просто убери решетки из текста. Это снимет с них заголовок.
#
# ![image.png](attachment:image.png)
#
#
#
# Зато можно добавлять заголовок перед тем или иным разделом. </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2<a class="tocSkip"></h2>
#
# <b>Спасибо, буду иметь ввиду:</b>

# %% [markdown]
# ## Составим портрет пользователя каждого региона
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#
# ### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# ### Задайте самостоятельно пороговое значение alpha.
#
# ### Поясните:
#
# #### Как вы сформулировали нулевую и альтернативную гипотезы;
#
# #### Какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# ## Напишем общий вывод

# %% [markdown]
# # Приступим к проекту

# %% [markdown]
# # Шаг 1 - Знакомство с данными

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.rcParams.update({'figure.max_open_warning': 0})
import warnings
warnings.filterwarnings('ignore')
from scipy import stats as st

# %%
try:
    data = pd.read_csv('/datasets/games.csv') #загрузим данные
except:
    data = pd.read_csv('games.csv')

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Загружать библиотеки лучше в отдельной ячейке. Иногда приходится что-то подгружать или обновлять. Если чтение таблицы будет рядом, то она перезапишется. Причем, всю загрузку лучше делать в начале проекта, тогда читателю будет сразу понятно, какие модули потребуются для запуска проекта.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Отлично.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Исправил, спасибо за совет</b>

# %%
data.head() #выведем первые строки датафрейма
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
data.info() #рассмотрим информацию датафрейма, мы видим что Year_of_Release написан в float64, User_score в object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
data.hist(figsize=(15, 20))#Построим общую гистограмму для всех числовых столбцов таблицы
plt.show()

# %%
data.isna().sum() # рассмотрим пропущенные значения
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %% [markdown]
# **Пройдя первый шаг, мы видим что Year_of_Release написан в float64, User_score в object переведем их к int. Пропущенные значения Name мы будем заменять на пустую строку " ", остальные значения Critic_Score, User_score, Rating оставим без изменений**

# %% [markdown]
# # Шаг 2 - Работа с данными

# %% [markdown]
# **Заменим названия столбцов и приведем их к нижнему регистру**

# %%
columns = ['name', 'platform','year_of_release','genre','na_sales','eu_sales', 'jp_sales','other_sales','critic_score','user_score','rating']
data.columns = columns #изменили названия столбцов и превели их к нижнему регистру

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ⚠️</h2>
#
# Вот так тоже сработает:
# </div>
#
# ```python
#
# df.columns = df.columns.str.lower()
# ```

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Спасибо, учту это</b>

# %% [markdown]
# **Преобразуйте данные в нужные типы**

# %%
data['year_of_release'] = data['year_of_release'].astype('Int64') #приведем столбец year_of_release к типу int
data['critic_score'] = data['critic_score'].astype('Int64') #приведем столбец critic_score к типу int

#Мы узнали, что в игровом пространстве расшифровка tbd - 'To Be Determined' - 'Будет определено'. Это тоже самое, что и "значение неизвестно", поэтому можем заменитть на Nan
#заменил tbd на nan чтоб форматнуть тип user_score 
data['user_score'] = data['user_score'].replace("tbd", np.NaN)
#приведем столбец user_score к типу Float64
#data['user_score'] = data['user_score'].astype(float) #сначала не давал заменить на float так-как были реликты tbd, заменим их на Nan

data['user_score'] = data['user_score'].astype(float)
data['user_score'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ⚠️</h2>
#
# Описательные комментарии следует выносить в отдельные ячейки типа Markdown. Посмотри, как код в них теряется. Комментарии к коду должны быть лаконичными. Они отвечают на вопрос *Что делаем?*, а не *Почему?* или *Зачем?*. Комментируют код в сложных местах, примитивные вещи оставляют без комментариев.</div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# > заменил tbd на nan чтоб форматнуть тип user_score
#
# Да, это допустимо.
#
# </div>

# %% [markdown]
# **Обработаем оставшиеся пропуски**

# %%
#с tbd мы разобрались ранее, который нам мешал

data.fillna ({"name" : " ","genre" : " "}, inplace=True) #заменим пропуски в имени и жанре на пропуск
#data.isna().sum() проверим, пропусков в имени и жанре нет.

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ⚠️</h2>
#
# - Быть может, стоит их просто удалить?
#
#
# - **inplace** не всегда отрабатывает корректно, поэтому лучше явно перезаписать столбец/таблицу.
# </div>

# %% [markdown]
# **Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец**

# %%
data['total_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales'] # сложим значения продаж
#америки , европы , японии и др.продаж в один и назовем его total_sales

data.head() #посмотрим что получилось
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45            76         8.0      E
# 1      3.58      6.81         0.77          <NA>         NaN    NaN
# 2     12.76      3.79         3.29            82         8.3      E
# 3     10.93      3.28         2.95            80         8.0      E
# 4      8.89     10.22         1.00          <NA>         NaN    NaN
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Можно еще взять метод **sum** с аргументом **axis=1**.
#
# </div>
#
# ```python
#
#
# df['total_sales'] = df[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)
# ```

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Дубликаты проверил, равны 0</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️ </h2>
#
# Это важная проверка, потому что иногда дубликаты могут испортить весь анализ.
#
# </div>

# %% [markdown]
# **Пройдя второй шаг, мы привели значения к нижнему регистру для удобства работы с данными, преобразовали данные к нужным нам типам, год и оценку критиков приравняли к типу int для работы с целыми числами, а оцнеку пользовтелей к типу с плавающей точкой. Мы заменили пропуски в имени и жанре для полноты анализируемых данных. Но не стали трогать столбцы critic_score, user_score, rating, так как доля пропущенных значений 50% у каждого значения, при замене мы можем исказить статистику.**
#
# **Мы узнали, что в игровом пространстве расшифровка tbd - 'To Be Determined' - 'Будет определено'. Это тоже самое, что и "значение неизвестно", поэтому можем заменили на Nan значения в user_score. Также мы добавили столбик total_sales с сумарными продажами во всех регионах**

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
#
# - Как думаешь, почему могли возникнуть все эти пропуски?
#
#
#
# - Не забывай проверять и на наличие дубликатов.</div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️ </h2>
#
# Вижу корректировки 👍
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Пропущенные значения встречаются в столбцах user_score, rating,critic_score.
#    Посмотрел по открытым источникам крупнейшие тематические журналы освещающие тематику компьютерных игр и платформ появились во второй половине 1990-х годов. Такие как metacritic(1999), IGN (1996), Игромания в России (1997) то вероятно, некоторые игры и платформы не получали оценку критиков, а игрокам негде было оставить свои рецензии.Крупнейшая организация на тот момент (ESRB) присуждающая оценку в нашей тематике была основана в 1994, также часть данных поэтому не была заполнена. А по нашим данным счет идет с 1980 г.</b>

# %% [markdown]
# # Шаг 3 - Исследовательский анализ данных

# %% [markdown]
# **Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?**

# %%
Number = data.groupby('year_of_release')[['name']].count() #посмотрим сколько игр выпускалось в разные годы
print(Number)
# Out:
#                  name
# year_of_release
# 1980                9
# 1981               46
# 1982               36
# 1983               17
# 1984               14
# 1985               14
# 1986               21
# 1987               16
# 1988               15
# 1989               17
# 1990               16
# 1991               41
# 1992               43
# 1993               62
# 1994              121
# 1995              219
# 1996              263
# 1997              289
# 1998              379
# 1999              338
# 2000              350
# 2001              482
# 2002              829
# 2003              775
# 2004              762
# 2005              939
# 2006             1006
# 2007             1197
# 2008             1427
# 2009             1426
# 2010             1255
# 2011             1136
# 2012              653
# 2013              544
# 2014              581
# 2015              606
# 2016              502

# %%
games_different_year = data.pivot_table(index='year_of_release', values='name', aggfunc='count') #построим график
plt.figure(figsize=(14,6))
sns.lineplot(data=games_different_year)
sns.set_style('darkgrid')
plt.title("Выпущенные игры в разные годы")
plt.xlabel("Год")
plt.ylabel("Количество игр")
plt.legend('')
plt.show()

# %% [markdown]
# **В целом до 1990 года темпы выпуска игр сохраняли свою динамику, но после 1990 года, когда ПК становится более доступным для некоторых категорий населения, выпуск игр увеличивается, так-как спрос на них становится выше. После 2000 года когда интенет и ПК становится обычным делом для всех, индустрия набирает максимальные обороты и каждый год увеличивает темпы роста. В целом игровая индустрия растет до 2010 года и резко падает, вероятно это связано с финансовым кризисом 2008 года, который ударил по всем отраслям экономики. На игровую индустрию он также оказал весомое значение**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Отличная визуализация. Уже по ней можно прикинуть актуальный период.
# </div>

# %% [markdown]
# **Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?**

# %%
leader_platform = data.groupby('platform')['total_sales'].sum().sort_values()[-5:].index.tolist() #посмотрим лидеров платформ
print(leader_platform)
# Out:
# ['DS', 'Wii', 'PS3', 'X360', 'PS2']

# %%
#сформируем график продаж пл платформам
platform_sale = data.pivot_table(index='platform', values='total_sales', aggfunc='sum').sort_values(by='total_sales', ascending=False)

plt.figure(figsize=(14,6))
sns.barplot(x=platform_sale.index,y=platform_sale['total_sales'])
plt.title("Продажи платформ за все время")
plt.xlabel("Платформа")
plt.ylabel("Продажи")
plt.show()

# %% [markdown]
# **Исходя из полученных данных, 5ка победителей это: ps2,x360.ps3,wii,ds**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Похоже на то. </div>

# %%
#изменим порядок индекса
platform_grouped = platform_sale.reset_index()

#Составим список всех платформ
top_platforms = platform_grouped['platform'].unique()
top_platforms

#составим продажи по каждой платформе по годам
for platform in top_platforms:
    data[data['platform'] == platform].pivot_table(index='year_of_release', values='total_sales', aggfunc='sum').plot(kind='bar', figsize=(14,6))
    plt.title(platform)

# %% [markdown]
# **Отталикаваясь от полученных данных мы можем утверждать, что средний жизненный цикл платфоормы 8-10 лет. Топ 5 платформ ps2,x360.ps3,wii,ds. Но уже к 2016 году их жизненный цикл подходит к концу**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Да, примерно столько они и живут.
#
# </div>
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <h2> Комментарий ревьюера  ⚠️</h2>
#
# Можно определять срок жизни по указанным выше топам. Просто потому, что туда не попали свежие консоли, которые свой срок еще не прожили, а также потому, что туда не попали неудачные консоли, которые прожили 2-3 года.
#
#
# Можно также попробовать вычислить срок жизни.
#
#
# </div>

# %% [markdown]
# **Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год**

# %%
#Возьмем данные за актуальный период с пика 2012 годов, когда игровая инлдустрия была на пике, но под конец 2016 года, многие
#платформы начали уходить и их стали заменять новые, это интересно.
interested_period_for_analys = data[data['year_of_release'] > 2012]
interested_period_for_analys.head(15)
# Out:
#                                          name platform  year_of_release  \
# 16                         Grand Theft Auto V      PS3             2013
# 23                         Grand Theft Auto V     X360             2013
# 31                  Call of Duty: Black Ops 3      PS4             2015
# 33                        Pokemon X/Pokemon Y      3DS             2013
# 42                         Grand Theft Auto V      PS4             2014
# 47  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS             2014
# 60                       Call of Duty: Ghosts     X360             2013
# 69                       Call of Duty: Ghosts      PS3             2013
# 72                                  Minecraft     X360             2013
# 77                                    FIFA 16      PS4             2015
# 87               Star Wars Battlefront (2015)      PS4             2015
# 92             Call of Duty: Advanced Warfare      PS4             2014
# ...

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
#
# Судя по первому графику, нам стоит начинать минимум с 2012 года, потому что продажи в 2011 уж очень сильно выбиваются.
#
# </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️ </h2>
#
# Так мы сделаем анализ более безопасным, потому что продажи 2011 года не будут искажать распределение последних лет.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Согласен, перестрою данные на период 2012 года.</b>

# %%
print(interested_period_for_analys['platform'].unique())
# Out:
# ['PS3' 'X360' 'PS4' '3DS' 'XOne' 'WiiU' 'Wii' 'PC' 'PSV' 'DS' 'PSP']

# %%
interested_period_for_analys.pivot_table(index='year_of_release', columns = 'platform', values='total_sales', aggfunc='sum').plot(grid=True, figsize=(14, 6))
plt.title('график продаж платформ')
plt.xlabel('временной период.')
plt.ylabel('продажи.')
plt.show()

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <h2> Комментарий ревьюера 2 ⚠️</h2>
#
# Столбец года можно попробовать привести к формату даты (year), чтобы на оси Х были целые числа.
# </div>

# %%
#суммируем все суммы по продажам платформ
interested_period_for_analys.groupby(['platform'])['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'total_sales'].apply(sum)
# Out:
#           na_sales  eu_sales  jp_sales  other_sales  total_sales
# platform
# 3DS          38.20     30.96     67.81         6.28       143.25
# DS            0.57      0.85      0.00         0.12         1.54
# PC           11.11     25.36      0.00         2.96        39.43
# PS3          63.50     67.81     23.35        26.77       181.43
# PS4         108.74    141.09     15.96        48.35       314.14
# PSP           0.00      0.17      3.29         0.04         3.50
# PSV           5.04      6.10     18.59         3.26        32.99
# Wii           6.56      5.93      0.05         1.12        13.66
# WiiU         29.21     19.85     10.88         4.69        64.63
# X360         81.66     42.52      0.51        12.11       136.80
# XOne         93.12     51.59      0.34        14.27       159.32

# %% [markdown]
# **В целом по всем платформам продажи падают, но есть главные фавориты с 2010 года, это ps3,ps4,xbox360,xone - это самые новые и перспективные платформы в те года**

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
#
# У x360 продажи почти ушли в ноль, у ps3 тоже довольно реззкое падение было. Посмотри на динамику по годам в сводной таблице Стоит ли нам называть их перспективными?
#
#
# Можно зато 3ds рассмотреть.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Согласен, рассмотрим 3ds.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️ </h2>
#
# Иногда я предпочитаю сводные таблицы графикам:
# </div>

# %%
# КОД РЕВЬЮЕРА 2

interested_period_for_analys.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
# Out:
# platform           3DS    DS     PC     PS3     PS4   PSP    PSV   Wii   WiiU  \
# year_of_release
# 2013             56.57  1.54  12.38  113.25   25.99  3.14  10.59  8.59  21.65
# 2014             43.76   NaN  13.28   47.76  100.00  0.24  11.90  3.75  22.03
# 2015             27.78   NaN   8.52   16.82  118.90  0.12   6.25  1.14  16.35
# 2016             15.14   NaN   5.25    3.60   69.25   NaN   4.25  0.18   4.60
#
# platform          X360   XOne
# year_of_release
# 2013             88.58  18.96
# 2014             34.74  54.07
# 2015             11.96  60.14
# 2016              1.52  26.15

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️ </h2>
#
# Здесь прекрасно видно, как сильно упали продажи у некоторых консолей. </div>

# %%
#создадим новую таблицу с главными фаворитами
interested_period_for_analys = interested_period_for_analys.query("platform == ['XOne', 'PS4', 'PS3', 'X360', '3DS']")
interested_period_for_analys
# Out:
#                                                 name platform  \
# 16                                Grand Theft Auto V      PS3
# 23                                Grand Theft Auto V     X360
# 31                         Call of Duty: Black Ops 3      PS4
# 33                               Pokemon X/Pokemon Y      3DS
# 42                                Grand Theft Auto V      PS4
# ...                                              ...      ...
# 16672  Metal Gear Solid V: The Definitive Experience     XOne
# 16674                  Tsukigime Ranko's Longest Day      PS3
# 16677               Aikatsu Stars! My Special Appeal      3DS
# 16691                   Dynasty Warriors: Eiketsuden      PS3
# 16710                  Samurai Warriors: Sanada Maru      PS3
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 16                2013        Action      7.02      9.09      0.98
# 23                2013        Action      9.66      5.14      0.06
# ...

# %%
#сделаем график
interested_period_for_analys.pivot_table(index='year_of_release', columns = 'platform', values='total_sales', aggfunc='sum').plot(grid=True, figsize=(14, 6))
plt.title('график продаж платформ')
plt.xlabel('продажи, тыс.')
plt.ylabel('Временной период.')
plt.show()

# %% [markdown]
# **По графику видно, что платформы ранее были на пике, это ps3,x360,3ds - спрос медленно снижается, в 2013 стартуют перспективные платформы и рынок по этим продуктам делает резкий скачек вверх PS4 все же охватывает больший сегмент чем Xone, но и они в течении 2015-2016г снижают продажи**

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
# Правильно ли я понимаю, что тут ты и делаешь вывод о том, что ps3 и x360 перспективными называть нельзя? Если да, то сформулируй, пожалуйста, более явно :)
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>За период с 2012 года по 2016 - PS3,x360,3ds все еще являются серьезными игроками рынка, они медленно снижают тендецию по продажам, но потребители все еще обращают на них внимание из-за большого количества выпущенных игр, поддержки и вероятно снижающейся цены. Когда приставки PS4 и XONE конечно рождают высокий спрос среди геймеров, которые предвкушенные грамотным маркетингом ждут новых консолей и их покупают. Сам таким являюсь, купил ps4 в 2013 и в период до 2015 было не более 6-8 игр на ней.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Хорошо.
#
# </div>

# %% [markdown]
# **Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.**

# %%
#применим дискрайб к результатам, самый высокий результат по продажам у ps3, вероятно стрельнула какая то игра
interested_period_for_analys.groupby('platform')['total_sales'].describe()
# Out:
#           count      mean       std   min   25%    50%    75%    max
# platform
# 3DS       303.0  0.472772  1.381347  0.01  0.04  0.090  0.280  14.60
# PS3       345.0  0.525884  1.451939  0.01  0.04  0.150  0.510  21.05
# PS4       392.0  0.801378  1.609456  0.01  0.06  0.200  0.730  14.63
# X360      186.0  0.735484  1.663275  0.01  0.08  0.265  0.795  16.27
# XOne      247.0  0.645020  1.036139  0.01  0.06  0.220  0.685   7.39

# %%
# построим общую диаграмму размаха

plt.rcParams["figure.figsize"] = [15, 25]
plt.rcParams["figure.autolayout"] = True

interested_period_for_analys.boxplot(column='total_sales', by='platform')

plt.title('Ящик с усами', fontsize=14)
plt.xlabel('Платформа', fontsize=14)
plt.ylabel('Глобальные продажи',fontsize=14)
plt.show()

# %% [markdown]
# **Построив общую диаграмму размаха,  видим большие размахи, вероятно это связано, с тем, что какие то игры набирали огромную популярность.**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Верно.
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px;border: 1px solid ">
# <b> Комментарий ревьюера  ❌</b>
#
#
# А что про сами консоли можно сказать? Если сравнить распределения их продаж, какой вывод можно сделать?
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Чуть выше описал уже. Повторюсь:  За период с 2012 года по 2016 - PS3,x360,3ds все еще являются серьезными игроками рынка, они медленно снижают тендецию по продажам, но потребители все еще обращают на них внимание из-за большого количества выпущенных игр, поддержки и вероятно снижающейся цены. Когда приставки PS4 и XONE конечно рождают высокий спрос среди геймеров, которые предвкушенные грамотным маркетингом ждут новых консолей и их покупают. Сам таким являюсь, купил ps4 в 2013 и в период до 2015 было не более 6-8 игр на ней.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Это я помню :) Тут я больше про боксплот спрашиваю. Смотри,боксплот это та же гистограмма. Только боксплот лучше, ведь нам не надо подбирать параметр bins, да и квартили на нем видны. Этот график удобно рассматривать при анализе распределений, особенно если они смещены.
#
# Что касается выбросов, то это какие-то популярные игры. И это очень показательная штука. Посмотри на 3DS. Маленький ящик и много выбросов. Это говорит о том, что большАя часть объема продаж делается за счет этих выбросов. В то же время у XOne ситуация иная: большой бокс, длинный ус и мало выбросов. Это свидетельствует о том, что на XOne покупают самые разные игры, причем, в немалом количестве.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2<a class="tocSkip"></h2>
#
# <b>Круто, спасибо за объяснение, boxplot стал понятен лучше.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 3 ✔️</h2>
#
# Рада помочь! Добавлю еще на всякий случай картинку:
#
#
# ![image.png](attachment:image.png)
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2<a class="tocSkip"></h2>
#
# <b>Теперь понятней еще лучше, круто. Спасибо!</b>

# %% [markdown]
# **Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Для диагностики возьмем PS4**

# %%
print("PS4 диаграмма рассеивания")
sns.pairplot(interested_period_for_analys[interested_period_for_analys.platform == "PS4"][['total_sales', 'critic_score', 'user_score']],height=5)
plt.show()
# Out:
# PS4 диаграмма рассеивания

# %%
print("Матрица корреляций PS4")
interested_period_for_analys[interested_period_for_analys.platform == "PS4"][['total_sales', 'critic_score', 'user_score']].corr()
# Out:
# Матрица корреляций PS4
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.406568   -0.031957
# critic_score     0.406568      1.000000    0.557654
# user_score      -0.031957      0.557654    1.000000

# %% [markdown]
# **Корреляция между PS4 total_sales и critic_score равна (0.40), корреляция между total_sales и user_score - (-0,03) - не выявлена**

# %% [markdown]
# **Рассмотрим другие платформы и сравним их.Перейдём к PS3**

# %%
print("PS3 диаграмма рассеивания")
sns.pairplot(interested_period_for_analys[interested_period_for_analys.platform == "PS3"][['total_sales', 'critic_score', 'user_score']],height=5)
plt.show()
# Out:
# PS3 диаграмма рассеивания

# %%
print("Матрица корреляций PS3")
interested_period_for_analys[interested_period_for_analys.platform == "PS3"][['total_sales', 'critic_score', 'user_score']].corr()
# Out:
# Матрица корреляций PS3
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.334285    0.002394
# critic_score     0.334285      1.000000    0.599920
# user_score       0.002394      0.599920    1.000000

# %% [markdown]
# ****Корреляция между PS3 total_sales и critic_score равна (0.33) - умеренная, корреляция между total_sales и user_score - (0,002) - корреляция не выявлена****

# %% [markdown]
# **Рассмотрим XOne**

# %%
print("Xone диаграмма рассеивания")
sns.pairplot(interested_period_for_analys[interested_period_for_analys.platform == "XOne"][['total_sales', 'critic_score', 'user_score']],height=5)
plt.show()
# Out:
# Xone диаграмма рассеивания

# %%
print("Матрица корреляций XOne")
interested_period_for_analys[interested_period_for_analys.platform == "XOne"][['total_sales', 'critic_score', 'user_score']].corr()
# Out:
# Матрица корреляций XOne
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.416998   -0.068925
# critic_score     0.416998      1.000000    0.472462
# user_score      -0.068925      0.472462    1.000000

# %% [markdown]
# **Корреляция между XOne total_sales и critic_score равна (0.41) - умеренная, корреляция между total_sales и user_score - (-0,06) - корреляция не выявлена**

# %% [markdown]
# **Рассмотрим X360**

# %%
print("X360 диаграмма рассеивания")
sns.pairplot(interested_period_for_analys[interested_period_for_analys.platform == "X360"][['total_sales', 'critic_score', 'user_score']],height=5)
plt.show()
# Out:
# X360 диаграмма рассеивания

# %%
print("Матрица корреляций X360")
interested_period_for_analys[interested_period_for_analys.platform == "X360"][['total_sales', 'critic_score', 'user_score']].corr()
# Out:
# Матрица корреляций X360
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.350345   -0.011742
# critic_score     0.350345      1.000000    0.520946
# user_score      -0.011742      0.520946    1.000000

# %% [markdown]
# **Корреляция между XOne total_sales и critic_score равна (0.35) - умеренная, корреляция между total_sales и user_score - (-0,01) - корреляция не выявлена**

# %% [markdown]
# **Рассмотрим 3ds**

# %%
print("3ds диаграмма рассеивания")
sns.pairplot(interested_period_for_analys[interested_period_for_analys.platform == "3DS"][['total_sales', 'critic_score', 'user_score']],height=5)
plt.show()
# Out:
# 3ds диаграмма рассеивания

# %%
print("Матрица корреляций 3ds")
interested_period_for_analys[interested_period_for_analys.platform == "3DS"][['total_sales', 'critic_score', 'user_score']].corr()
# Out:
# Матрица корреляций 3ds
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.357057    0.241504
# critic_score     0.357057      1.000000    0.769536
# user_score       0.241504      0.769536    1.000000

# %% [markdown]
# **Корреляция между XOne total_sales и critic_score равна (0.35) - умеренная, корреляция между total_sales и user_score - (0,24) - корреляция слабая**

# %% [markdown]
# **У всех платформ наблюдается умеренная связь между продажами и оценками критинов, что касается корреляции между продажами и оценками пользователи - ее практически нет**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера ✔️</h2>
#
# Да, похоже на правду.
# </div>

# %% [markdown]
# **Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?**

# %%
#посмотрим продажи по жарнрам за все время
all_genre = data.pivot_table(index="genre",values="total_sales",aggfunc='sum').sort_values(by="total_sales",ascending=False).reset_index().rename_axis(None, axis=1)
all_genre
# Out:
#            genre  total_sales
# 0         Action      1744.17
# 1         Sports      1331.27
# 2        Shooter      1052.45
# 3   Role-Playing       934.56
# 4       Platform       827.77
# 5           Misc       802.51
# 6         Racing       728.67
# 7       Fighting       447.53
# 8     Simulation       389.97
# 9         Puzzle       242.57
# 10     Adventure       237.59
# 11      Strategy       174.23
# 12                       2.42

# %% [markdown]
# **На первых местах Action, sports, shooter,roleplay**

# %%
plt.figure(figsize=(12,6))
plt.title('Все игры по жарнам ',fontsize=20)
sns.barplot(data=all_genre, x='genre', y='total_sales')
plt.xlabel('Жанры',fontsize=12)
plt.ylabel('Количество копий',fontsize=12)
plt.show()

# %% [markdown]
# **На первом месте action игры, предпочтения людей понятны. В таких жанрах не нужно обдумывать собственные поступки, поскольку действовать необходимо быстро и решительно, опираясь на собственные рефлексы и реакцию. Что касается стратегий, то это всегда была не очень популярный жанр, так-как необходимо продумывать свои дейсвия и игры такого жанра быстро надоедают основной массе игроманов, не считая ценителей этого жанра.**

# %% [markdown]
# **Расчитаем по среднему значению**

# %%
all_genre_mean = data.pivot_table(index="genre",values="total_sales",aggfunc='mean').sort_values(by="total_sales",ascending=False).reset_index().rename_axis(None, axis=1)
all_genre_mean
# Out:
#            genre  total_sales
# 0                    1.210000
# 1       Platform     0.932173
# 2        Shooter     0.795503
# 3   Role-Playing     0.623872
# 4         Racing     0.583403
# 5         Sports     0.566980
# 6       Fighting     0.527126
# 7         Action     0.517711
# 8           Misc     0.458577
# 9     Simulation     0.446701
# 10        Puzzle     0.418224
# 11      Strategy     0.255095
# 12     Adventure     0.182341

# %%
plt.figure(figsize=(12,6))
plt.title('Все игры по жарнам, среднее ',fontsize=20)
sns.barplot(data=all_genre_mean, x='genre', y='total_sales')
plt.xlabel('Жанры',fontsize=12)
plt.ylabel('Количество копий',fontsize=12)
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>По жанрам, сделал по средней. Результаты изменились, на первом 1 - без данных, 2 - платформеры, 3 - шутеры, 4 - ролевые, 5 - гонки</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Игры без жанра можно не учитывать, ведь там всего два экемпляра.
#
# </div>

# %% [markdown]
# **Расчитаем по медиане**

# %%
all_genre_median = data.pivot_table(index="genre",values="total_sales",aggfunc='median').sort_values(by="total_sales",ascending=False).reset_index().rename_axis(None, axis=1)
all_genre_median
# Out:
#            genre  total_sales
# 0                        1.21
# 1       Platform         0.27
# 2        Shooter         0.24
# 3         Sports         0.22
# 4       Fighting         0.21
# 5         Action         0.19
# 6         Racing         0.19
# 7   Role-Playing         0.18
# 8           Misc         0.16
# 9     Simulation         0.15
# 10        Puzzle         0.11
# 11      Strategy         0.10
# 12     Adventure         0.05

# %%
plt.figure(figsize=(12,6))
plt.title('Все игры по жарнам, медиана ',fontsize=20)
sns.barplot(data=all_genre_median, x='genre', y='total_sales')
plt.xlabel('Жанры',fontsize=12)
plt.ylabel('Количество копий',fontsize=12)
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>По медиане. Результаты изменились, на первом 1 - без данных, 2 - платформеры, 3 - шутеры, 4 - гонки, 5 - файтинги</b>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера ❌ </b>
#
#
# - Не используется актуальный период.
#
#
#
# - Вообще, про прибыльность мы тут говорить не можем, ведь речь о млн копий, да и нет у нас информации о себестоимости. Тут имеется в виду скорее успешность в продажах. Хорошо. А может ли быть такая ситуация, что экшн делает продажи только за счет большего количества игр и большого количества бестселлеров? Быть может, другие жанры имеют больше продаж в расчете на единицу игры. Сделай то же самое, но с медианными/средними  продажами.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Период приведен с 2010 к 2012. Добавил к сравнению 3DS, для 3ds сделана оценка.По жанрам сделал оценку по средней и медиане, они отличаются, на первом месте игры без данных, в обоих случая на втором месте платформеры, 3 и 4 у средних значений шутеры и ролевые на 5 месте гонки. По медиане на 3 и 4  месте шутеры и гонки, на пятом - файтинги</b>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера 2 ❌ </b>
#
#
# Да, но в вычислениях выше используется  таблица `data`, которая содержит данные за все 30 лет.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2<a class="tocSkip"></h2>
#
# <b>Попробую ниже переделать по срезу</b>

# %%
new_platform_table = data[data['year_of_release']>2012]
#посмотрим продажи по жарнрам за все время
all_genre_our_table = new_platform_table.pivot_table(index="genre",values="total_sales",aggfunc='sum').sort_values(by="total_sales",ascending=False).reset_index().rename_axis(None, axis=1)
all_genre_our_table
# Out:
#            genre  total_sales
# 0         Action       321.87
# 1        Shooter       232.98
# 2         Sports       150.65
# 3   Role-Playing       145.89
# 4           Misc        62.82
# 5       Platform        42.63
# 6         Racing        39.89
# 7       Fighting        35.31
# 8      Adventure        23.64
# 9     Simulation        21.76
# 10      Strategy        10.08
# 11        Puzzle         3.17

# %%
plt.figure(figsize=(12,6))
plt.title('Все игры по жарнам ',fontsize=20)
sns.barplot(data=all_genre_our_table, x='genre', y='total_sales')
plt.xlabel('Жанры',fontsize=12)
plt.ylabel('Количество копий',fontsize=12)
plt.show()

# %% [markdown]
# **На первом месте action,shooter,sport,rp,misc.**

# %%
all_genre_our_table_mean = new_platform_table.pivot_table(index="genre",values="total_sales",aggfunc='mean').sort_values(by="total_sales",ascending=False).reset_index().rename_axis(None, axis=1)
all_genre_our_table_mean
# Out:
#            genre  total_sales
# 0        Shooter     1.245882
# 1         Sports     0.703972
# 2       Platform     0.576081
# 3   Role-Playing     0.499623
# 4         Racing     0.469294
# 5       Fighting     0.441375
# 6         Action     0.420196
# 7           Misc     0.405290
# 8     Simulation     0.350968
# 9         Puzzle     0.186471
# 10      Strategy     0.180000
# 11     Adventure     0.096490

# %%
plt.figure(figsize=(12,6))
plt.title('Все игры по жарнам ',fontsize=20)
sns.barplot(data=all_genre_our_table_mean, x='genre', y='total_sales')
plt.xlabel('Жанры',fontsize=12)
plt.ylabel('Количество копий',fontsize=12)
plt.show()

# %% [markdown]
# **По средним значениям по нашему срезу шутеры, спорт, платформеры, рп, гонки**

# %%
all_genre_our_table_median = new_platform_table.pivot_table(index="genre",values="total_sales",aggfunc='median').sort_values(by="total_sales",ascending=False).reset_index().rename_axis(None, axis=1)
all_genre_our_table_median
# Out:
#            genre  total_sales
# 0        Shooter        0.450
# 1         Sports        0.240
# 2       Platform        0.225
# 3   Role-Playing        0.125
# 4       Fighting        0.125
# 5         Racing        0.120
# 6         Action        0.110
# 7     Simulation        0.100
# 8           Misc        0.100
# 9       Strategy        0.080
# 10        Puzzle        0.060
# 11     Adventure        0.030

# %%
plt.figure(figsize=(12,6))
plt.title('Все игры по жарнам ',fontsize=20)
sns.barplot(data=all_genre_our_table_median, x='genre', y='total_sales')
plt.xlabel('Жанры',fontsize=12)
plt.ylabel('Количество копий',fontsize=12)
plt.show()

# %% [markdown]
# **По медианным значениям по нашему срезу шутеры, спорт, платформеры, рп, гонки**

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2<a class="tocSkip"></h2>
#
# <b>Сейчас они везде одинаковые)</b>

# %% [markdown]
# <div class="alert alert-success " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 3 ✔️</h2>
#
# Теперь экшн не такой популярный :) Это нам говорит о том, что у этого жанра очень много игр, которые мало покупают. А вот у шутера гораздо больше игр покупают в большом количестве.
#
# </div>

# %% [markdown]
# **Выводы по исследовательскому анализу:**
#
# **-За все время по платформам лидирует PS2, Х360, PS3**
#
# **-За период с 2012 года по 2016 - PS3,x360,3ds все еще являются серьезными игроками рынка, они медленно снижают тендецию по продажам, но потребители все еще обращают на них внимание из-за большого количества выпущенных игр, поддержки и вероятно снижающейся цены. Когда приставки PS4 и XONE конечно рождают высокий спрос среди геймеров, которые предвкушенные грамотным маркетингом ждут новых консолей и их покупают.**
#
#
# **У всех платформ с 2010 наблюдается умеренная связь между продажами и оценками критинов, что касается корреляции между продажами и оценками пользователи - ее практически нет**
#
# **-Жизненный цикл платформы установлен в 10 лет**
#
# **За все время больше всего игр продано Action, sports, shooter,roleplay**

# %% [markdown]
# # Шаг 4 - Составьте портрет пользователя каждого региона

# %% [markdown]
# **Определите для пользователя каждого региона (NA, EU, JP):
# Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# Самые популярные жанры (топ-5). Поясните разницу.
# Влияет ли рейтинг ESRB на продажи в отдельном регионе?.**

# %% [markdown]
# **Рассмотрим данные по продажам топ5 платформ на рынке северной америки. Рассмотрим по общим данным и данным с 2010г**

# %%
#Выведем топ платформ северной америки по общей таблице
na_platform = data.groupby('platform')['na_sales'].sum().sort_values(ascending=False)
print(na_platform.head())
# Out:
# platform
# X360    602.47
# PS2     583.84
# Wii     496.90
# PS3     393.49
# DS      382.40
# Name: na_sales, dtype: float64

# %%
#построим гистограмму по данным общим данным северной америки
na_platform.plot(x = 'platform', y = 'na_sales', kind = 'bar', figsize=(14,6), grid=True, title = 'График популярных платформ Северная Америка',fontsize=20)
plt.xlabel('Наименование платформы',fontsize=20)
plt.ylabel('Продажи в млн.',fontsize=20)
plt.show()

# %% [markdown]
# **По общим данным, топ 5 популярных платформ в Северной Америке - X360, PS2, WII, PS3, DS. Х360 обходит PS2 на 20 млн.ед, и практически в 2 раза DS. Сейчас рассмотрим по данным с 2010г**

# %%
#Выведем топ платформ северной америки по нашей таблице
#na_platform_our_table = interested_period_for_analys.groupby('platform')['na_sales'].sum().sort_values(ascending=False)
#print(na_platform_our_table.head())

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Закоментил строку где вывожу по платформам, следующей строкой выводу по годам к Северной Америке</b>

# %%
new_platform_table = data[data['year_of_release']>2012]
#Выведем топ платформ северной америки по нашей таблице с учетом замечаний
na_new_platform_table = new_platform_table.groupby('platform')['na_sales'].sum().sort_values(ascending=False)
print(na_new_platform_table.head())
# Out:
# platform
# PS4     108.74
# XOne     93.12
# X360     81.66
# PS3      63.50
# 3DS      38.20
# Name: na_sales, dtype: float64

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2  ✔️</h2>
#
# Вижу срез по периоду 👍</div>

# %%
#построим гистограмму по данным нашей таблицы
na_new_platform_table.plot(x = 'platform', y = 'na_sales', kind = 'bar', figsize=(14,6), grid=True, title = 'График популярных платформ Северная Америка с 2012г',fontsize=20)
plt.xlabel('Наименование платформы',fontsize=20)
plt.ylabel('Продажи в млн.',fontsize=20)
plt.show()

# %% [markdown]
# **В Северной Америке топ5 платформ по данным с 2012г - 1) PS4 2) Xone 3) X360 4) PS3 5)3DS.**

# %% [markdown]
# **Рассмотрим данные по продажам топ5 платформ на рынке европы. Рассмотрим по общим данным и данным с 2012г**

# %%
#Выведем топ платформ европы по общей таблице
eu_platform = data.groupby('platform')['eu_sales'].sum().sort_values(ascending=False)
print(eu_platform.head())
# Out:
# platform
# PS2     339.29
# PS3     330.29
# X360    270.76
# Wii     262.21
# PS      213.61
# Name: eu_sales, dtype: float64

# %%
#построим гистограмму по данным общим данным европы
eu_platform.plot(x = 'platform', y = 'eu_sales', kind = 'bar', figsize=(14,6), grid=True, title = 'График популярных платформ Европы',fontsize=20)
plt.xlabel('Наименование платформы',fontsize=20)
plt.ylabel('Продажи в млн.',fontsize=20)
plt.show()

# %% [markdown]
# **В европе по общим данным, лидер рынка PS 2, PS3, x360, wii, ps. Значительная доля продаж приходится на PS2 и PS3. Рассмотрим по нашим данным**

# %%
#Выведем топ платформ северной америки по нашей таблице
#eu_platform_our_table = interested_period_for_analys.groupby('platform')['eu_sales'].sum().sort_values(ascending=False)
#print(eu_platform_our_table.head())

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Закоментил строку где вывожу по платформам, следующей строкой выводу по годам к Европе</b>

# %%
#Выведем топ платформ северной америки по нашей таблице с учетом замечаний Европа
eu_new_platform_table = new_platform_table.groupby('platform')['eu_sales'].sum().sort_values(ascending=False)
print(eu_new_platform_table.head())
# Out:
# platform
# PS4     141.09
# PS3      67.81
# XOne     51.59
# X360     42.52
# 3DS      30.96
# Name: eu_sales, dtype: float64

# %%
#построим гистограмму по данным нашей таблицы
eu_new_platform_table.plot(x = 'platform', y = 'eu_sales', kind = 'bar', figsize=(14,6), grid=True, title = 'График популярных платформ Европы с 2012г',fontsize=20)
plt.xlabel('Наименование платформы',fontsize=20)
plt.ylabel('Продажи в млн.',fontsize=20)
plt.show()

# %% [markdown]
# **В Северной Америке топ5 платформ по данным с 2012г - 1) PS4 2) PS3 3) Xone 4) x360 5)3DS.**

# %% [markdown]
# **Рассмотрим данные по продажам топ5 платформ на рынке японии. Рассмотрим по общим данным и данным с 2012г**

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Распределения могут поменяться после корректировки периода.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Да, значения поменялись</b>

# %%
#Выведем топ платформ японии по общей таблице
jp_platform = data.groupby('platform')['jp_sales'].sum().sort_values(ascending=False)
print(jp_platform.head())
# Out:
# platform
# DS      175.57
# PS      139.82
# PS2     139.20
# SNES    116.55
# 3DS     100.67
# Name: jp_sales, dtype: float64

# %%
#построим гистограмму по данным общим данным европы
jp_platform.plot(x = 'platform', y = 'jp_sales', kind = 'bar', figsize=(14,6), grid=True, title = 'График популярных платформ Япония',fontsize=20)
plt.xlabel('Наименование платформы',fontsize=20)
plt.ylabel('Продажи в млн.',fontsize=20)
plt.show()

# %% [markdown]
# **В Японии по общим данным, лидеры рынка DS,PS,PS2,SNES,3DS. Значительная доля продаж приходится на DS. Рассмотрим по нашим данным**

# %%
#Выведем топ платформ японии по нашей таблице
#jp_platform_our_table = interested_period_for_analys.groupby('platform')['jp_sales'].sum().sort_values(ascending=False)
#print(jp_platform_our_table.head())

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Закоментил строку где вывожу по платформам, следующей строкой выводу по годам к Японии</b>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера  ❌</b>
#
# Надо выбрать 5 консолей, а в таблице их 4 :) Используй просто срез по годам, не ограничивая анализ консолями. Нам ведь надо топ внутри регионов найти, а не анализировать распределение топа по регионам. </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Да, так и сделал</b>

# %%
#Выведем топ платформ северной америки по нашей таблице с учетом замечаний Япония
jp_new_platform_table = new_platform_table.groupby('platform')['jp_sales'].sum().sort_values(ascending=False)
print(jp_new_platform_table.head())
# Out:
# platform
# 3DS     67.81
# PS3     23.35
# PSV     18.59
# PS4     15.96
# WiiU    10.88
# Name: jp_sales, dtype: float64

# %%
#построим гистограмму по данным нашей таблицы
jp_new_platform_table.plot(x = 'platform', y = 'jp_sales', kind = 'bar', figsize=(14,6), grid=True, title = 'График популярных платформ Японии с 2012г',fontsize=20)
plt.xlabel('Наименование платформы',fontsize=20)
plt.ylabel('Продажи в млн.',fontsize=20)
plt.show()

# %% [markdown]
# **В Японии топ5 платформ по данным с 2012г - 1) 3DS 2) PS3 3) PSV 4) PS4 5)WiiU.**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Похоже, что японцы больше любят портативные консоли и родной рынок. Игры на иксбоксы там продвигать точно не стоит :)
# </div>

# %% [markdown]
# **Рассмотрим данные по продажам топ5 платформ на остальных рынках. Рассмотрим по общим данным и данным с 2010г**

# %%
#Выведем топ платформ японии по общей таблице
other_platform = data.groupby('platform')['other_sales'].sum().sort_values(ascending=False)
print(other_platform.head())
# Out:
# platform
# PS2     193.44
# PS3     135.68
# X360     85.76
# Wii      79.07
# DS       59.26
# Name: other_sales, dtype: float64

# %%
#построим гистограмму по общим данным для других регионов
other_platform.plot(x = 'platform', y = 'other_sales', kind = 'bar', figsize=(14,6), grid=True, title = 'График популярных платформ по остальным регионам',fontsize=20)
plt.xlabel('Наименование платформы',fontsize=20)
plt.ylabel('Продажи в млн.',fontsize=20)
plt.show()

# %% [markdown]
# **В остальных регионах доминируют такие платформы PS2,PS3,x360,wii,ds.Рассмотрим по данным с 2010г**

# %%
#Выведем топ платформ японии по нашей таблице
#other_platform_our_table = interested_period_for_analys.groupby('platform')['other_sales'].sum().sort_values(ascending=False)
#print(other_platform_our_table.head())

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Закоментил строку где вывожу по платформам, следующей строкой выводу по годам к другим регионам</b>

# %%
#Выведем топ платформ северной америки по нашей таблице с учетом замечаний Япония
other_new_platform_table = new_platform_table.groupby('platform')['other_sales'].sum().sort_values(ascending=False)
print(other_new_platform_table.head())
# Out:
# platform
# PS4     48.35
# PS3     26.77
# XOne    14.27
# X360    12.11
# 3DS      6.28
# Name: other_sales, dtype: float64

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# В этом распределении продукция Майкрософт тоже не в топе :) </div>

# %%
#построим гистограмму по данным нашей таблицы для остальных регионов
other_new_platform_table.plot(x = 'platform', y = 'other_sales', kind = 'bar', figsize=(14,6), grid=True, title = 'График популярных платформ остальных регионов с 2012г',fontsize=20)
plt.xlabel('Наименование платформы',fontsize=20)
plt.ylabel('Продажи в млн.',fontsize=20)
plt.show()

# %% [markdown]
# **В Японии топ5 платформ по данным с 2012г - 1) PS4 2) PS3 3) Xone 4) x360 5)3ds.**

# %% [markdown]
# **Вывод по данным ТОП-5 платформ по регионам**
#
# По общим данным ТОП 5:
# Северная Америка - X360, PS2, WII, PS3, DS
#
# Европа- PS 2, PS3, x360, wii, ps.
#
# Япония - DS,PS,PS2,SNES,3DS
#
# Другие регионы - PS2,PS3,x360,wii,ds
#
# **По нашим данным 2012г:**
#
# Северная Америка - 1) PS4 2) Xone 3) X360 4) PS3 5)3DS.
#
# Европа- 1) PS4 2) PS3 3) Xone 4) x360 5)3DS.
#
# Япония - 1) 3DS 2) PS3 3) PSV 4) PS4 5)WiiU
#
# Другие регионы - 1) PS4 2) PS3 3) Xone 4) x360 5)3ds.

# %% [markdown]
# **Рассмотрим ТОП 5 жанров по рынкам. Данные с 2012г**

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера  ❌</b>
#
# Здесь и далее убедись, пожалуйста, что используется актуальнй период без среза по консолям. </div>
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Супер!
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Готово, вывод заменил</b>

# %%
# ТОП-5 самых популярных жанров в Северной Америке по общей таблице
genre_na = data.groupby('genre')['na_sales'].sum().sort_values(ascending=False)
#построим гистограмму
genre_na.plot(x = 'genre', y = 'na_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'ТОП-5 самых популярных жанров в Северной Америке общая таблица')
plt.xlabel('Жанр',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %%
# ТОП-5 самых популярных жанров в Северной Америке по общей таблице
genre_na = new_platform_table.groupby('genre')['na_sales'].sum().sort_values(ascending=False)
#построим гистограмму
genre_na.plot(x = 'genre', y = 'na_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'ТОП-5 самых популярных жанров в Северной Америке с 2012')
plt.xlabel('Жанр',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 2 ❌</b>
#
# В ячейке выше используется старая таблицаю В ячейке ниже хоть и используется таблица с актуальным периодом, но там содержатся лишь 5 консолей. Как мы уже знаем, в Японии свой топ, поэтому не стоит анализировать популярность жанров в Японии только по мировому топу. Кроме того, нам важно посмотреть распределение жанров вообще, независимо от консолей.
#
#
# Проще всего сделать срез по таблице data перед анализом жанров. Тогда останется лишь удалить ненужные ячейки.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2<a class="tocSkip"></h2>
#
# <b>Понял, исправился, переменная сейчас new_platform_table за период. Вывод изменил</b>

# %% [markdown]
# <div class="alert alert-success " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 3 ✔️</h2>
#
# Хорошо.
# </div>

# %%
# ТОП-5 самых популярных жанров в Северной Америке по общей таблице
genre_na_our_table = new_platform_table.groupby('genre')['na_sales'].sum().sort_values(ascending=False)
#построим гистограмму
genre_na_our_table.plot(x = 'genre', y = 'na_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'ТОП-5 самых популярных жанров в Северной Америке c 2010')
plt.xlabel('Жанр',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %% [markdown]
# **Топ 5 жанров в Северной Америке по общим данным - Action,sports,shooter,platform,misc. По нашим данным - action, shooter,sport,role-play,misc**

# %% [markdown]
# **Рассмотрим рынок Европы по жанрам**

# %%
# ТОП-5 самых популярных жанров в Северной Америке по общей таблице
genre_eu = data.groupby('genre')['eu_sales'].sum().sort_values(ascending=False)
#построим гистограмму
genre_eu.plot(x = 'genre', y = 'eu_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'ТОП-5 самых популярных жанров в Европе общие данные')
plt.xlabel('Жанр',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %%
# ТОП-5 самых популярных жанров в Северной Америке по нашей таблице
genre_eu_our_table = new_platform_table.groupby('genre')['eu_sales'].sum().sort_values(ascending=False)
#построим гистограмму
genre_eu_our_table.plot(x = 'genre', y = 'eu_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'ТОП-5 самых популярных жанров в Европе с 2010')
plt.xlabel('Жанр',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %% [markdown]
# **Топ 5 жанров в Европе по общим данным - Action,sports,shooter,racing,misc. По нашим данным - action, shooter,sports,role-play,racing**

# %% [markdown]
# **Рассмотрим рынок Японии по жанрам**

# %%
# ТОП-5 самых популярных жанров в Японии по общей таблице
genre_jp = data.groupby('genre')['jp_sales'].sum().sort_values(ascending=False)
#построим гистограмму
genre_jp.plot(x = 'genre', y = 'jp_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'ТОП-5 самых популярных жанров в Японии общая')
plt.xlabel('Жанр',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %%
# ТОП-5 самых популярных жанров в Японии по общей таблице
genre_jp_our_table = new_platform_table.groupby('genre')['jp_sales'].sum().sort_values(ascending=False)
#построим гистограмму
genre_jp_our_table.plot(x = 'genre', y = 'jp_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'ТОП-5 самых популярных жанров в Японии c 2012')
plt.xlabel('Жанр',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %% [markdown]
# **Топ 5 жанров в Японии по общим данным - role-play,action,sports,platform,misc. По нашим данным - rele-play,action,misc,fighting,shooter**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 3 ✔️</h2>
#
# А еще в Японии не очень-то и любят шутеры, которые очень популярны на Западе. Видимо, им больше нравятся мечи в РПГ и мордобой в файтингах. </div>

# %% [markdown]
# **Рассмотрим рынок других регионов по жанрам**

# %%
# ТОП-5 самых популярных жанров в других регионах по общей таблице
genre_other = data.groupby('genre')['other_sales'].sum().sort_values(ascending=False)
#построим гистограмму
genre_other.plot(x = 'genre', y = 'other_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'ТОП-5 самых популярных жанров в другом регионе')
plt.xlabel('Жанр',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %%
# ТОП-5 самых популярных жанров в других регионах по нашей таблице
genre_other_our_table = new_platform_table.groupby('genre')['other_sales'].sum().sort_values(ascending=False)
#построим гистограмму
genre_other_our_table.plot(x = 'genre', y = 'other_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'ТОП-5 самых популярных жанров в других регионах')
plt.xlabel('Жанр',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %% [markdown]
# **Топ 5 жанров в Японии по общим данным - action,sports,shooter,racing,misc. По нашим данным - action,shooter,sports,role-play,racing**

# %% [markdown]
# **Вывод по данным ТОП-5 жанров по регионам**
#
# По общим данным ТОП 5:
# Северная Америка -  Action,sports,shooter,platform,misc.
#
# Европа- Action,sports,shooter,racing,misc.
#
# Япония - role-play,action,sports,platform,misc.
#
# Другие регионы - action,sports,shooter,racing,misc
#
# **По нашим данным:**
#
# Северная Америка -  action, shooter,sport,role-play,misc
#
# Европа- action, shooter,sports,role-play,racing
#
# Япония - rele-play,action,misc,fighting,shooter
#
# Другие регионы - action,shooter,sports,role-play,racing
#
# **Практически во всех регионах экшены и шутеры на первых местах, все потому, что здесь нет возможности обдумывать собственные поступки, поскольку действовать необходимо быстро и решительно, опираясь на собственные рефлексы и реакцию, поэтому такие игры намного проще как в освоении, так и в легкости освоения.**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 3 ✔️</h2>
#
# Отлично, тут все корректно теперь. Рассмотрены как данные за все года, так и данные за актуальный период.
#
# </div>

# %% [markdown]
# **Влияет ли рейтинг ESRB на продажи в отдельном регионе?**
#
# Е - Подходит для всех возрастных категорий.
#
# EC - Для детей младшего возраста
#
# E 10+	Подходит для лиц старше 10 лет
#
# T	Подходит для лиц старше 13 лет.
#
# M	Подходит для лиц старше 17 лет.
#
# AO	Подходит для взрослых старше 18 лет.
#
# RP	Категория ещё не присвоена.

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера  ❌</b>
#
# Здесь необходимо рассмотреть также и отсутствующий возрастной рейтинг, предварительно заменив его на маркерное значение. Например, на *Нет рейтинга*. С маркером пропуски тоже отобразятся в таблице или на графике, и мы увидим их распределение продаж по регионам. Эта задача является отличным примером того, что даже пропущенные значения могут нести в себе важную информацию. Не забудь прокомментировать результат и выдвинуть предположение о причинах разницы распределений, если она будет.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Большая часть игр осталась без изменений. Топовые компании дающие возрастной рейтинг это ESRB(1994), PEGI(2003), USK(1994), CERO(2002) все они основаны после 1994 года, а наша статистика с 1980г, поэтому рейтинг некому было тогда ставить и они все шли без рейтинга. Плюс игры без рейтинга не поппадают под ограничения той или иной группы, следовательно мы не ограничивает целевую аудиторию.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Отличная гипотеза. Посмотрим на результаты :)
# </div>

# %%
data["rating"] = data['rating'].fillna("No rating")
unique_rating = data['rating'].unique().tolist()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера 2 ❌</b>
#
# Напоминаю про то, что весь анализ стоит проводить в рамках одного и того же временного интервала :) </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2<a class="tocSkip"></h2>
#
# <b>Два интервала ниже взял, общий и с 2012.</b>

# %% [markdown]
# **Посмотрим рейтинг в Северной Америке**

# %%
# Рейтинг в Северной Америке
rating_na = data.groupby('rating')['na_sales'].sum().sort_values(ascending=False)
#построим гистограмму
rating_na.plot(x = 'genre', y = 'na_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'Рейтинг в Северной Америке')
plt.xlabel('категория',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %%
for_rating_exersize = data[data['year_of_release']>2012]

# %% [markdown]
# <div class="alert alert-success " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 4 ✔️</h2>
#
# Отлично, новый срез сделан.
#
#
# Вообще, в подобных проектах ты можешь сразу создавать таблицу с актуальным периодом. А если возникает необходимость как-то иначе заполнить пропуски, добавляй этот код заполнения в раздел предобработки. Тогда тебе останется только запустить проект целиком, чтобы изменения вступили в силу.
# </div>

# %%
# Рейтинг в Северной Америке
rating_na_our = for_rating_exersize.groupby('rating')['na_sales'].sum().sort_values(ascending=False)
#построим гистограмму
rating_na_our.plot(x = 'genre', y = 'na_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'Рейтинг в Северной Америке')
plt.xlabel('категория',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <b> Комментарий ревьюера 3 ❌</b>
#
# Обращаю твое внимание на то, что заполнение пропусков было произведено в таблице data после того, как из нее была срезана таблица new_platform_table.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 3<a class="tocSkip"></h2>
#
# <b>Понял, сейчас исправлюсь.</b>
#
#    <b>Готово, теперь все вроде получается.
#     Северная Америка - M , No rating, E, E10+, T.
#     Европа - M , No rating, E, E10+, T.
#     Япония - No rating,T, E, M, E10+
#     Другие регионы - M,no rating, E,T,E10+<b>

# %% [markdown]
# **Самый высокий рейтинг Е(для всех),на втором месте игры без рейтинга ,далее идут T(старше 13) и М(старше 17), самое маленькое количество у Е10+(старше 10)**
#
# **по данным с 2012г" M(от 17), E(для всех),Е10+(от 10), Т(старше 13)**

# %% [markdown]
# **Рассмотрим Европу**

# %%
# Рейтинг в Европе
rating_eu = data.groupby('rating')['eu_sales'].sum().sort_values(ascending=False)
#построим гистограмму
rating_eu.plot(x = 'genre', y = 'eu_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'Рейтинг в Европе')
plt.xlabel('категория',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %%
# Рейтинг в Европе
rating_eu_our = for_rating_exersize.groupby('rating')['eu_sales'].sum().sort_values(ascending=False)
#построим гистограмму
rating_eu_our.plot(x = 'genre', y = 'eu_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'Рейтинг в Европе')
plt.xlabel('категория',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %% [markdown]
# **Самый высокий рейтинг Е(для всех), на втором месте игры без рейтинга, на третьем М (старше 17), на четвертом Т(от 13) и самая маленькая е10+**

# %% [markdown]
# **Рассмотрим Японию**

# %%
# Рейтинг в Японии
rating_jp = data.groupby('rating')['jp_sales'].sum().sort_values(ascending=False)
#построим гистограмму
rating_jp.plot(x = 'genre', y = 'jp_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'Рейтинг в Японии')
plt.xlabel('категория',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %%
# Рейтинг в Японии
rating_jp_our = for_rating_exersize.groupby('rating')['jp_sales'].sum().sort_values(ascending=False)
#построим гистограмму
rating_jp_our.plot(x = 'genre', y = 'jp_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'Рейтинг в Японии наши данные')
plt.xlabel('категория',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %% [markdown]
# <div class="alert alert-success " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 4 ✔️</h2>
#
# Теперь четко видно, что независимо от периода в Японии лидируют игры без возрастного рейтинга.
# </div>

# %% [markdown]
# **Самый высокий рейтинг у игр без рейтинга, на втором месте Е(для всех), на третьем месте Т(от 13 лет) на четвертом М(от 17 лет), на пятом Е10+(старше 10)**
#
# **по нашим данным Т(от 13 лет),Е(для всех),М(от 17 лет),Е10+(старше 10)**

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Япония снова отличилась. Скорее всего, дело тут в том, что ESRB работает только на территории СА, в Японии есть аналогичная организация: CERO. Я думаю, что, с одной стороны, иностранным играм они (ESRB) не присваивают рейтинги, поскольку на них уже есть маркировка. Чтобы не было конфликта, так сказать. Так что вполне возможно, что часть игр это продукция Японии или же это корейские игры (там тоже своя организация). С другой стороны, раз они продают игры на своем рынке, то присвоение рейтинга может быть обязательным. Значит, дело еще может быть в том, что наша таблица это склейка двух таблиц: продажи на Западе и на Востоке. Так или иначе, это очень показательный пример. И именно разница в рынках (восточный и западный) наталкивает на мысль о неслучайности пропусков.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Прикольно. На счет конфликта, посмотри какие рейтинги у игры Sims 4, там каждая компания поставила свою оценку от "без рейтинга" до "18+" :D .</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 3 ✔️</h2>
#
# 😊
# </div>

# %% [markdown]
# **Рассмотрим другие регионы**

# %%
# Рейтинг в Другие регионы
rating_other = data.groupby('rating')['other_sales'].sum().sort_values(ascending=False)
#построим гистограмму
rating_other.plot(x = 'genre', y = 'other_sales', kind = 'bar', figsize=(14,8), grid=True, title = 'рейтинг другие регионы')
plt.xlabel('категория',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %%
# Рейтинг в Японии
rating_other_our = for_rating_exersize.groupby('rating')['other_sales'].sum().sort_values(ascending=False)
#построим гистограмму
rating_other_our.plot(x = 'genre', y = 'jp_sales', kind = 'bar', figsize=(20,8), grid=True, title = 'Рейтинг в другие регионы наши данные')
plt.xlabel('категория',fontsize=20)
plt.ylabel('Продажи экземпляров (млн.)',fontsize=20)
plt.show()

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера  ⚠️</b>
#
# Кстати, чем больше размер графика, тем более мелкими становятся подписи. 14 на 8 тут вполне достаточно будет. </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Спасибо за информацию</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Рада помочь :)
# </div>

# %% [markdown]
# **Самый высокий рейтинг Е(для всех), на втором месте М(от 17 лет) и на третьем T(от 13 лет),на четвертом игры без рейтинга ,на пятом Е10+(старше 10).**

# %% [markdown]
# **Вывод рейтингу**
#
# По общим данным
# Северная Америка -  Самый высокий рейтинг Е(для всех),на втором месте игры без рейтинга ,далее идут T(старше 13) и М(старше 17), самое маленькое количество у Е10+(старше 10)
#
# Европа- Самый высокий рейтинг Е(для всех), на втором месте игры без рейтинга, на третьем М (старше 17), на четвертом Т(от 13) и самая маленькая е10+
#
# Япония - Самый высокий рейтинг у игр без рейтинга, на втором месте Е(для всех), на третьем месте Т(от 13 лет) на четвертом М(от 17 лет), на пятом Е10+(старше 10)
#
# Другие регионы - Самый высокий рейтинг Е(для всех), на втором месте М(от 17 лет) и на третьем T(от 13 лет),на четвертом игры без рейтинга ,на пятом Е10+(старше 10).
#
# С маркером пропуски заменили на "без рейтинга", количество таких игр достаточно высокое
#
# Рейтинг влияет следующим образом, так-как большая часть геймеров это люди более менее осознанного возраста, они покупают себе игры с категорий Е. Категория Е10+ больше покупается родителями своим детям, чаще всего это проекты не такие популярные как в категории Е. Данные практически одинаковы во всех регионах, чаще покупают игры с пометкой Е и без рейтинга( для всех)

# %% [markdown]
# **Вернемся к топ 5 платформам по регионам и рассмотрим различия в долях продаж**

# %%
#переменной value_all_platform_sales присваиваем сумму общих продаж по всем платформам
value_all_platform_sales = data.groupby('platform')['total_sales'].sum()

# %% [markdown]
# **Рассмотрим Северную Америку**

# %%
#общее количество платформ в Америке
platform_na = new_platform_table.groupby('platform')['na_sales'].sum()

percent_na = platform_na / value_all_platform_sales * 100
display(percent_na.sort_values(ascending=False).head(5))

# %% [markdown]
# **Рассмотрим Европу**

# %%
#общее количество платформ в Европе
platform_eu = new_platform_table.groupby('platform')['eu_sales'].sum()

percent_eu = platform_eu / value_all_platform_sales * 100
display(percent_eu.sort_values(ascending=False).head(5))

# %% [markdown]
# **Рассмотрим Японию**

# %%
#общее количество платформ в Японии
platform_jp = new_platform_table.groupby('platform')['jp_sales'].sum()

percent_jp = platform_jp / value_all_platform_sales * 100
display(percent_jp.sort_values(ascending=False).head(5))

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <h2> Комментарий ревьюера 2 ⚠️</h2>
#
# Тут по долям как раз и видно, что в Японии иная ситуация, поэтому стоит анализировать топ-5 региона, а не мира.</div>

# %% [markdown]
# **Рассмотрим другие регионы**

# %%
#общее количество платформ в других регионах
platform_other = new_platform_table.groupby('platform')['other_sales'].sum()

percent_other = platform_other / value_all_platform_sales * 100
display(percent_other.sort_values(ascending=False).head(5))

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <h2> Комментарий ревьюера  ⚠️</h2>
#
# Напоминаю про период :) </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Готово, сейчас по периоду</b>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <h2> Комментарий ревьюера 2 ⚠️</h2>
#
# Почти :) </div>

# %% [markdown]
# **Вывод по долям продаж в регионах**
#
# По общим данным
# Северная Америка - на регион Северной Америки платформы занимают следующее отношение к общему количеству платформ с 2012г - Xone - 58,44%, WiiU-35,53%, PS4 - 34,61%, 3DS - 14,74%, PSV-9,32%
#
# Европа - на регион Европы платформы занимают следующее отношение к общему количеству платформ с 2012г - PS4 - 44,91%, Xone-32,38%, WiiU - 24,15%, 3DS - 11,95%, PSV-11,28%
#
# Япония - на регион Японии платформы занимают следующее отношение к общему количеству платформ с 2012г - PSV - 34,38%, 3ds-26,18%, WiiU - 13,23%, PS4 - 5,08%, PS3-2,48%
#
#
# Другие регионы - на другие регионы платформы занимают следующее отношение к общему количеству платформ с 2012г - PS4 - 15,39%, Xone-8,95%, PSV - 6,02%, PS4 - 5,70%, PS3-2,84%

# %% [markdown]
# # Шаг 5 - Проверьте гипотезы

# %% [markdown]
# -Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#
#
# -Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
#
# Задайте самостоятельно пороговое значение alpha.
#
# Поясните:
#
#
# -Как вы сформулировали нулевую и альтернативную гипотезы;
#
#
# -Какой критерий применили для проверки гипотез и почему.**

# %% [markdown]
# **Сформулируем нулевые гипотезы**
#
# Нулевая гипотеза: Средние пользовательские рейтинги xboxone и pc одинаковые;
#
# Альтернативная гипотеза: Средние пользовательские рейтинги xboxone и pc различаются

# %%
#сохраним в переменных данные за 10 лет
xbox_one_stat = data[(data['platform']=='XOne') & (data['year_of_release']>2012)]['user_score']
pc_stat = data[(data['platform']=='PC') & (data['year_of_release']>2012)]['user_score']

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера  ❌</b>
#
# Не ясно, почему используется такой срез. </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Это мое решение, решил взять 10 лет. Сделал срез с 2012</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 2 ✔️</h2>
#
# Ясно. Просто скажу тогда, что если весь анализ идет в одном периоде, то и гипотезы стоит проводить в нем же. Нам не так важна информация 10-летней давности.
# </div>

# %%
#посчитаем средний рейтинг профиля пользователей для xbox
xbox_one_stat.mean()

# %%
#посчитаем средний рейтинг профиля пользователей для pc
pc_stat.mean()

# %%
#рассмотрим дисперсии выборки xone
np.var(data[data['platform']=='XOne']['user_score'])

# %%
#рассмотрим дисперсии выборки pc
np.var(data[data['platform']=='PC']['user_score'])

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <h2> Комментарий ревьюера 2 ⚠️</h2>
#
# Обращаю твое внимание на то, что дисперсии в итоге сраниваются по старой таблице.</div>

# %%
#попробуем проверить гипотезу методом T-test так как с его помощью можно сравнить средние двух совокупностей и одна из наиболее часто используемых процедур в статистике.

alpha = 0.01

results=st.ttest_ind(xbox_one_stat.dropna(),pc_stat.dropna(), equal_var=False)

print('p-критерий:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")

# %% [markdown]
# **Значение 0.14. У нас не получилось отвергнуть нулевую гипотезу.**

# %% [markdown]
# **Сформулируем нулевые гипотезы**
#
# Нулевая гипотеза: Средние пользовательские рейтинги жанров Action и Sports одинаковые.
#
# Альтернативная гипотеза: Средние пользовательские рейтинги жанров Action и Sports различаются.

# %%
#сохраним в переменных данные за 10 лет
genre_action = data[(data['genre']=='Action') & (data['year_of_release']>2012)]['user_score']
genre_sport = data[(data['genre']=='Sports') & (data['year_of_release']>2012)]['user_score']

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера  ❌</b>
#
# Здесь то же самое.</div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Сделал срез с 2012</b>

# %%
#посмотрим среднюю оценгку жанра экшн
genre_action.mean()

# %%
#посмотрим среднюю оценку жанра спорт
genre_sport.mean()

# %%
#рассмотрим дисперсии выборки экшн
np.var(data[data['genre']=='Action']['user_score'])

# %%
#рассмотрим дисперсии выборки экшн
np.var(data[data['genre']=='Sports']['user_score'])

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <h2> Комментарий ревьюера 2 ⚠️</h2>
#
# Тут тоже дисперсии по старой таблице сравниваются. Вообще, ты можешь всегда полагать, что диспресии разные. Можно их даже не сравнивать, потому что дисперсия напрямую зависит от среднего, а получить идентичные средние - маловероятно. </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>Ясно</b>

# %%
#также попробуем с ttest

alpha = 0.01

results=st.ttest_ind(genre_action.dropna(),genre_sport.dropna(), equal_var=False)

print('p-критерий:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")

# %% [markdown]
# **Значение 1.44. Мы отвергли нулевую гипотезу, мы не сможем получить одинаковые пользовательские рейтинги жанров.**

# %% [markdown]
# **Вывод**
#
# **Гипотеза "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые" - Не получилось отвергнуть нулевую гипотезу;**
#
#
# **Гипотеза" Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные. -  Нулевая гипотеза отвергнута**

# %% [markdown]
# # Шаг 6 - Вывод

# %% [markdown]
# Перед анализом данных мы подготовили данные и подготовили их к полноценному анализу.
#
#  мы привели значения к нижнему регистру для удобства работы с данными, преобразовали данные к нужным нам типам, год и оценку критиков приравняли к типу int для работы с целыми числами, а оцнеку пользовтелей к типу с плавающей точкой. Мы заменили пропуски в имени и жанре для полноты анализируемых данных. Но не стали трогать столбцы critic_score, user_score, rating, так как доля пропущенных значений 50% у каждого значения, при замене мы можем исказить статистику.
#
# Мы узнали, что в игровом пространстве расшифровка tbd - 'To Be Determined' - 'Будет определено'. Это тоже самое, что и "значение неизвестно", поэтому можем заменили на Nan значения в user_score. Также мы добавили столбик total_sales с сумарными продажами во всех регионах
#
# На этапе исследовательского анализа, мы узнали что В целом до 1990 года темпы выпуска игр сохраняли свою динамику, но после 1990 года, когда ПК становится более доступным для некоторых категорий населения, выпуск игр увеличивается, так-как спрос на них становится выше. После 2000 года когда интенет и ПК становится обычным делом для всех, индустрия набирает максимальные обороты и каждый год увеличивает темпы роста. В целом игровая индустрия растет до 2010 года и резко падает, вероятно это связано с финансовым кризисом 2008 года, который ударил по всем отраслям экономики. На игровую индустрию он также оказал весомое значение
#
# Мы узнали, что исходя из полученных данных 5-ка фаворитов по продажам это: ps2,x360.ps3,wii,ds.Отталикаваясь от полученных данных мы можем утверждать, что средний жизненный цикл платфоормы 8-10 лет. Проанализировав дополнительно данные с 2010 года, мы узнали, что фаворитами в этом цикле являются - ps3,ps4,xbox360,xonе. Согласно графику видно, что платформы ранее были на пике, это ps3,x360 - спрос медленно снижается, в 2013 стартуют перспективные платформы и рынок по этим продуктам делает резкий скачек вверх PS4 все же охватывает больший сегмент чем Xone, но и они в течении 2015-2016г снижают продажи. Построив общую диаграмму размаха, видим большие размахи, вероятно это связано, с тем, что какие то игры набирали огромную популярность. Корреляция между XOne total_sales и critic_score равна (0.35) - умеренная, корреляция между total_sales и user_score - (0,24) - корреляция слабая. У всех платформ наблюдается умеренная связь между продажами и оценками критинов, что касается корреляции между продажами и оценками пользователи - ее практически нет. Мы узнали, что На первом месте action игры, предпочтения людей понятны. В таких жанрах не нужно обдумывать собственные поступки, поскольку действовать необходимо быстро и решительно, опираясь на собственные рефлексы и реакцию. Что касается стратегий, то это всегда была не очень популярный жанр, так-как необходимо продумывать свои дейсвия и игры такого жанра быстро надоедают основной массе игроманов, не считая ценителей этого жанра.
#
# Мы подготовили портрет пользователя каждого региона, мы рассмотрели и определили самые популярные платформы.
# Вывод по данным ТОП-5 платформ по регионам
#
# По общим данным ТОП 5: Северная Америка - X360, PS2, WII, PS3, DS
#
# Европа- PS 2, PS3, x360, wii, ps.
#
# Япония - DS,PS,PS2,SNES,3DS
#
# Другие регионы - PS2,PS3,x360,wii,ds
#
# По нашим данным 2012г:
#
# Северная Америка - 1) PS4 2) Xone 3) X360 4) PS3 5)3DS.
#
# Европа- 1) PS4 2) PS3 3) Xone 4) x360 5)3DS.
#
# Япония - 1) 3DS 2) PS3 3) PSV 4) PS4 5)WiiU
#
# Другие регионы - 1) PS4 2) PS3 3) Xone 4) x360 5)3ds.
#
#
#
# Описали различия в долях продаж:
# По общим данным Северная Америка - на регион Северной Америки платформы занимают следующее отношение к общему количеству платформ с 2012г - Xone - 58,44%, WiiU-35,53%, PS4 - 34,61%, 3DS - 14,74%, PSV-9,32%
#
# Европа - на регион Европы платформы занимают следующее отношение к общему количеству платформ с 2012г - PS4 - 44,91%, Xone-32,38%, WiiU - 24,15%, 3DS - 11,95%, PSV-11,28%
#
# Япония - на регион Японии платформы занимают следующее отношение к общему количеству платформ с 2012г - PSV - 34,38%, 3ds-26,18%, WiiU - 13,23%, PS4 - 5,08%, PS3-2,48%
#
# Другие регионы - на другие регионы платформы занимают следующее отношение к общему количеству платформ с 2012г - PS4 - 15,39%, Xone-8,95%, PSV - 6,02%, PS4 - 5,70%, PS3-2,84%
#
#
#
#
# Выяснили самые популярные жанры
#
# По общим данным ТОП 5: Северная Америка - Action,sports,shooter,platform,misc.
#
# Европа- Action,sports,shooter,racing,misc.
#
# Япония - role-play,action,sports,platform,misc.
#
# Другие регионы - action,sports,shooter,racing,misc
#
# По нашим данным:
#
# Северная Америка - Shooter, Action, sports, role-play, misc
#
# Европа- action, shooter,sports,role-play,racing
#
# Япония - action,role-play,shooter,fighting,sports
#
# Другие регионы - action,shooter,sports,role-play,racing
# Практически во всех регионах экшены и шутеры на первых местах, все потому, что здесь нет возможности обдумывать собственные поступки, поскольку действовать необходимо быстро и решительно, опираясь на собственные рефлексы и реакцию, поэтому такие игры намного проще как в освоении, так и в легкости освоения.
#
#
# Узнали как влияет рейтинг ERSB
# По общим данным Северная Америка - Самый высокий рейтинг Е(для всех),на втором месте игры без рейтинга ,далее идут T(старше 13) и М(старше 17), самое маленькое количество у Е10+(старше 10)
#
# Европа- Самый высокий рейтинг Е(для всех), на втором месте игры без рейтинга, на третьем М (старше 17), на четвертом Т(от 13) и самая маленькая е10+
#
# Япония - Самый высокий рейтинг у игр без рейтинга, на втором месте Е(для всех), на третьем месте Т(от 13 лет) на четвертом М(от 17 лет), на пятом Е10+(старше 10)
#
# Другие регионы - Самый высокий рейтинг Е(для всех), на втором месте М(от 17 лет) и на третьем T(от 13 лет),на четвертом игры без рейтинга ,на пятом Е10+(старше 10).
#
# С маркером пропуски заменили на "без рейтинга", количество таких игр достаточно высокое
#
# Рейтинг влияет следующим образом, так-как большая часть геймеров это люди более менее осознанного возраста, они покупают себе игры с категорий Е. Категория Е10+ больше покупается родителями своим детям, чаще всего это проекты не такие популярные как в категории Е. Данные практически одинаковы во всех регионах, чаще покупают игры с пометкой Е и без рейтинга( для всех)
#
#
# Топовые компании дающие возрастной рейтинг это ESRB(1994), PEGI(2003), USK(1994), CERO(2002) все они основаны после 1994 года, а наша статистика с 1980г, поэтому рейтинг некому было тогда ставить и они все шли без рейтинга. Плюс игры без рейтинга не поппадают под ограничения той или иной группы, следовательно мы не ограничивает целевую аудиторию.
#
# Мы проверили гипотезы:
# Мы сформулировали и проанализировали гипотезы.
#
# Гипотеза "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые" - Не получилось отвергнуть нулевую гипотезу;
#
# Гипотеза" Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные. - Нулевая гипотеза отвергнута

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера  ✔️</h2>
#
# Отличный вывод! Здорово, что подкрепляешь его ключевыми результатами - это хороший тон. Можно делать его чуть более компактным.
#
# </div>
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера ❌</b>
#
#
# Также не забудь обновить вывод после внесения изменений.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# <b>В вывод внес изменения согласно новой информации</b>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid">
# <b> Комментарий ревьюера 2 ❌</b>
#
#
# Супер! Однако напомню, что не везде был скорректирован период, поэтому результаты еще могут поменяться.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента 2<a class="tocSkip"></h2>
#
# <b>Цифры немного изменились, вывод привел к новым</b>

# %% [markdown]
# <div class="alert alert-success " style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Комментарий ревьюера 4 ✔️</h2>
#
# Отличная работа получилась :)
# </div>
